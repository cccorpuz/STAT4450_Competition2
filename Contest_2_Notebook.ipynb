# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import lightgbm as lgb
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_curve, auc
import gc
import scipy.ndimage
from fastai.tabular.all import *
from google.colab import drive

# %% [markdown]
# Importing train.csv and test.csv

# %%
train = pd.read_csv("/content/drive/MyDrive/STAT4450_contest2_data/train.csv")
test = pd.read_csv("/content/drive/MyDrive/STAT4450_contest2_data/test.csv")

# %% [markdown]
# Removing fake results from test dataframe

# %%
test_codes = test["ID_code"].values
test.drop(["ID_code"], axis=1, inplace=True)
test = test.values

unique_count = np.zeros_like(test)  # same col & row size
for i in tqdm(range(test.shape[1])):
    _, index_, count_ = np.unique(test[:, i], return_counts=True, return_index=True)
    unique_count[index_[count_ == 1], i] += 1

real_idx = np.argwhere(np.sum(unique_count, axis=1) > 0)[:, 0]
synth_idx = np.argwhere(np.sum(unique_count, axis=1) == 0)[:, 0]

test_length = test.shape[0]
test_synth = test[synth_idx, :]
test = test[real_idx, :]

# 2. Append real test to training
target = np.array(list(train["target"].values))
train_length = train.shape[0]
train.drop(["ID_code"], axis=1, inplace=True)
train.drop(["target"], axis=1, inplace=True)
full = pd.DataFrame(np.concatenate([train.values, test]), columns=train.columns)
synth = pd.DataFrame(test_synth, columns=train.columns)
print(full.shape)

# Reverse features with negative correlation
features = [x for x in full.columns if x.startswith("var")]
for var in features:
    if np.corrcoef(target, train[var])[1][0] < 0:
        full[var] = full[var] * -1

# Getting Counts, Density, Deviation
sigma_fac = 0.001
sigma_base = 4
eps = 0.00000001
# Out:
#  75%|███████▌  | 150/200 [00:05<00:01, 30.82it/s]

# %% [markdown]
# Defining a function to get feature counts

# %%
def get_features(data):
    # Get counts
    features_count = np.zeros((data.shape[0], len(features)))
    features_density = np.zeros((data.shape[0], len(features)))
    features_deviation = np.zeros((data.shape[0], len(features)))

    sigmas = []
    for i, var in enumerate(tqdm(features)):
        data_int = (data[var].values * 10000).round().astype(int)
        low = data_int.min()
        data_int -= low
        high = data_int.max() + 1
        counts_data = np.bincount(data_int, minlength=high).astype(float)

        # Geometric mean of twice sigma_base and a sigma_scaled which is scaled to the length of array
        sigma_scaled = counts_data.shape[0] * sigma_fac
        sigma = np.power(sigma_base * sigma_base * sigma_scaled, 1 / 3)
        sigmas.append(sigma)
        counts_data_smooth = scipy.ndimage.filters.gaussian_filter1d(counts_data, sigma)
        deviation = counts_data / (counts_data_smooth + eps)
        indices = data_int
        features_count[:, i] = counts_data[indices]
        features_density[:, i] = counts_data_smooth[indices]
        features_deviation[:, i] = deviation[indices]

    features_count_names = [var + "_count" for var in features]
    features_density_names = [var + "_density" for var in features]
    features_deviation_names = [var + "_deviation" for var in features]

    data_count = pd.DataFrame(columns=features_count_names, data=features_count)
    data_count.index = data.index
    data_density = pd.DataFrame(columns=features_density_names, data=features_density)
    data_density.index = data.index
    data_deviation = pd.DataFrame(
        columns=features_deviation_names, data=features_deviation
    )
    data_deviation.index = data.index
    data = pd.concat([data, data_count, data_density, data_deviation], axis=1)

    features_count = features_count_names
    features_density = features_density_names
    features_deviation = features_deviation_names

    return data, features_count, features_density, features_deviation

# %% [markdown]
# Getting the features and standardizing features

# %%
full, features_count, features_density, features_deviation = get_features(full)
(
    synth,
    fake_features_count,
    fake_features_density,
    fake_features_deviation,
) = get_features(synth)
print(full.shape)
print(f"test_synth: {synth.shape}")

# Standardizing the features
features_to_scale = [features, features_count]

scaler = StandardScaler()
features_to_scale_flatten = [var for sublist in features_to_scale for var in sublist]
scaler.fit(full[features_to_scale_flatten])
features_scaled = scaler.transform(full[features_to_scale_flatten])
full[features_to_scale_flatten] = features_scaled
print(full.shape)

# Split back into train and test
train = full.iloc[:train_length, :]
test = full.iloc[train_length:, :]
del full

gc.collect()
print(train.shape, test.shape)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]<ipython-input-4-e1a7dee16065>:19: DeprecationWarning: Please use `gaussian_filter1d` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   counts_data_smooth = scipy.ndimage.filters.gaussian_filter1d(counts_data, sigma)
# 100%|██████████| 200/200 [00:12<00:00, 16.21it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]<ipython-input-4-e1a7dee16065>:19: DeprecationWarning: Please use `gaussian_filter1d` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   counts_data_smooth = scipy.ndimage.filters.gaussian_filter1d(counts_data, sigma)
# 100%|██████████| 200/200 [00:08<00:00, 23.78it/s]
# (300000, 800)
# test_synth: (100000, 800)
# (300000, 800)
# (200000, 800) (100000, 800)

# %% [markdown]
# Light Gradient Boosting Machine (LGBM)

# %%
x_train, x_val, y_train, y_val = train_test_split(
    train, target, test_size=0.3, random_state=123
)

train_data = lgb.Dataset(x_train, label=y_train)
val_data = lgb.Dataset(x_val, label=y_val)


# Param notes:
# 1. base
# 2. reg_lambda to 0.1 improve by 3%, num_leaves = 16
# 3. reg_lambda to 0.5
# 4. num_leaves to 64
# 5. num_leaves to 128, max_bin to 512
# 6. learning_rate to 0.05, num_rounds to 500
# 7. feature_fraction to 0.9
# 8*. Kazuki Onodera's submission params

# num_rounds = 500
# params = {
#     "boost_from_average": "false",
#     "boost": "gbdt",
#     "feature_fraction": 0.9,
#     "learning_rate": 0.05,
#     "max_depth": -1,
#     "metric": "binary_logloss",
#     "num_leaves": 64,
#     "num_threads": 4, #Only 4 Colab Pro cores
#     "tree_learner": "serial",
#     "objective": "binary",
#     "reg_alpha": 2, #Reduces features
#     "reg_lambda": 0.5, 
#     "verbosity": 1,
#     "max_bin": 512,
# }

# 8* model params below:
num_rounds = 1600
params = {
    'bagging_freq': 5,
    'bagging_fraction': 1.0,
    'boost_from_average':'false',
    'boost': 'gbdt',
    'feature_fraction': 1.0,
    'learning_rate': 0.05,
    'max_depth': -1,
    'metric':'binary_logloss',
    'min_data_in_leaf': 30,
    'min_sum_hessian_in_leaf': 10.0,
    'num_leaves': 64,
    'num_threads': 8,
    'tree_learner': 'serial',
    'objective': 'binary',
    'verbosity': -1
    }

# train the model
model = lgb.train(params, train_data, num_rounds, valid_sets=[val_data])

# make predictions on the validation data
# y_pred = model.predict(x_val)

# print the accuracy
# accuracy = accuracy_score(y_val, y_pred.round().astype(int))
# print(accuracy)

# Make final prediction for test
sub = pd.DataFrame({"ID_code": test_codes})

pred_real = model.predict(test)
pred_synth = model.predict(synth)

preds_all = np.zeros(test_length)
preds_all[real_idx] = pred_real
preds_all[synth_idx] = pred_synth
sub["target"] = preds_all
sub.to_csv("/content/drive/MyDrive/STAT4450_contest2_data/lgbsubmission7.csv", index=False)
print(sub.head(20))
# Out:
# [1]	valid_0's binary_logloss: 0.689868
# [2]	valid_0's binary_logloss: 0.686627
# [3]	valid_0's binary_logloss: 0.683414
# [4]	valid_0's binary_logloss: 0.680231
# [5]	valid_0's binary_logloss: 0.677076
# [6]	valid_0's binary_logloss: 0.673958
# [7]	valid_0's binary_logloss: 0.670867
# [8]	valid_0's binary_logloss: 0.667803
# [9]	valid_0's binary_logloss: 0.664772
# [10]	valid_0's binary_logloss: 0.66177
# [11]	valid_0's binary_logloss: 0.658795
# [12]	valid_0's binary_logloss: 0.655857
# [13]	valid_0's binary_logloss: 0.652941
# [14]	valid_0's binary_logloss: 0.650054
# [15]	valid_0's binary_logloss: 0.647197
# [16]	valid_0's binary_logloss: 0.644369
# [17]	valid_0's binary_logloss: 0.641564
# [18]	valid_0's binary_logloss: 0.638785
# [19]	valid_0's binary_logloss: 0.63603
# [20]	valid_0's binary_logloss: 0.633303
# [21]	valid_0's binary_logloss: 0.630602
# [22]	valid_0's binary_logloss: 0.627925
# [23]	valid_0's binary_logloss: 0.625274
# [24]	valid_0's binary_logloss: 0.622646
# [25]	valid_0's binary_logloss: 0.620044
# [26]	valid_0's binary_logloss: 0.617466
# [27]	valid_0's binary_logloss: 0.614911
# [28]	valid_0's binary_logloss: 0.612377
# [29]	valid_0's binary_logloss: 0.609864
# [30]	valid_0's binary_logloss: 0.60738
# [31]	valid_0's binary_logloss: 0.604918
# [32]	valid_0's binary_logloss: 0.602481
# [33]	valid_0's binary_logloss: 0.600062
# [34]	valid_0's binary_logloss: 0.59766
# [35]	valid_0's binary_logloss: 0.595283
# [36]	valid_0's binary_logloss: 0.59293
# [37]	valid_0's binary_logloss: 0.590596
# [38]	valid_0's binary_logloss: 0.588279
# [39]	valid_0's binary_logloss: 0.585995
# [40]	valid_0's binary_logloss: 0.583725
# [41]	valid_0's binary_logloss: 0.581476
# [42]	valid_0's binary_logloss: 0.57925
# [43]	valid_0's binary_logloss: 0.577033
# [44]	valid_0's binary_logloss: 0.574842
# [45]	valid_0's binary_logloss: 0.572673
# [46]	valid_0's binary_logloss: 0.570523
# [47]	valid_0's binary_logloss: 0.568389
# [48]	valid_0's binary_logloss: 0.566275
# [49]	valid_0's binary_logloss: 0.564169
# [50]	valid_0's binary_logloss: 0.562096
# [51]	valid_0's binary_logloss: 0.560035
# [52]	valid_0's binary_logloss: 0.557994
# [53]	valid_0's binary_logloss: 0.555969
# [54]	valid_0's binary_logloss: 0.553958
# [55]	valid_0's binary_logloss: 0.551967
# [56]	valid_0's binary_logloss: 0.549993
# [57]	valid_0's binary_logloss: 0.548031
# [58]	valid_0's binary_logloss: 0.546092
# [59]	valid_0's binary_logloss: 0.544169
# [60]	valid_0's binary_logloss: 0.542261
# [61]	valid_0's binary_logloss: 0.540371
# [62]	valid_0's binary_logloss: 0.538495
# [63]	valid_0's binary_logloss: 0.536628
# [64]	valid_0's binary_logloss: 0.534783
# [65]	valid_0's binary_logloss: 0.532955
# [66]	valid_0's binary_logloss: 0.531137
# [67]	valid_0's binary_logloss: 0.529336
# [68]	valid_0's binary_logloss: 0.527551
# [69]	valid_0's binary_logloss: 0.525784
# [70]	valid_0's binary_logloss: 0.524024
# [71]	valid_0's binary_logloss: 0.522287
# [72]	valid_0's binary_logloss: 0.520562
# [73]	valid_0's binary_logloss: 0.518852
# [74]	valid_0's binary_logloss: 0.517151
# [75]	valid_0's binary_logloss: 0.515462
# [76]	valid_0's binary_logloss: 0.513788
# [77]	valid_0's binary_logloss: 0.512133
# [78]	valid_0's binary_logloss: 0.510489
# [79]	valid_0's binary_logloss: 0.508855
# [80]	valid_0's binary_logloss: 0.507242
# [81]	valid_0's binary_logloss: 0.505641
# [82]	valid_0's binary_logloss: 0.504053
# [83]	valid_0's binary_logloss: 0.502468
# [84]	valid_0's binary_logloss: 0.500905
# [85]	valid_0's binary_logloss: 0.499352
# [86]	valid_0's binary_logloss: 0.497806
# [87]	valid_0's binary_logloss: 0.49628
# [88]	valid_0's binary_logloss: 0.494769
# [89]	valid_0's binary_logloss: 0.493269
# [90]	valid_0's binary_logloss: 0.491775
# [91]	valid_0's binary_logloss: 0.490289
# [92]	valid_0's binary_logloss: 0.488819
# [93]	valid_0's binary_logloss: 0.487358
# [94]	valid_0's binary_logloss: 0.485918
# [95]	valid_0's binary_logloss: 0.484488
# [96]	valid_0's binary_logloss: 0.483068
# [97]	valid_0's binary_logloss: 0.481655
# [98]	valid_0's binary_logloss: 0.480257
# [99]	valid_0's binary_logloss: 0.478868
# [100]	valid_0's binary_logloss: 0.477487
# [101]	valid_0's binary_logloss: 0.476123
# [102]	valid_0's binary_logloss: 0.474773
# [103]	valid_0's binary_logloss: 0.473426
# [104]	valid_0's binary_logloss: 0.472093
# [105]	valid_0's binary_logloss: 0.470768
# [106]	valid_0's binary_logloss: 0.469455
# [107]	valid_0's binary_logloss: 0.468151
# [108]	valid_0's binary_logloss: 0.466857
# [109]	valid_0's binary_logloss: 0.465578
# [110]	valid_0's binary_logloss: 0.464298
# [111]	valid_0's binary_logloss: 0.463033
# [112]	valid_0's binary_logloss: 0.46178
# [113]	valid_0's binary_logloss: 0.460537
# [114]	valid_0's binary_logloss: 0.459305
# [115]	valid_0's binary_logloss: 0.458078
# [116]	valid_0's binary_logloss: 0.456859
# [117]	valid_0's binary_logloss: 0.455653
# [118]	valid_0's binary_logloss: 0.454457
# [119]	valid_0's binary_logloss: 0.453269
# [120]	valid_0's binary_logloss: 0.452092
# [121]	valid_0's binary_logloss: 0.450931
# [122]	valid_0's binary_logloss: 0.449769
# [123]	valid_0's binary_logloss: 0.448617
# [124]	valid_0's binary_logloss: 0.447476
# [125]	valid_0's binary_logloss: 0.446335
# [126]	valid_0's binary_logloss: 0.445211
# [127]	valid_0's binary_logloss: 0.444101
# [128]	valid_0's binary_logloss: 0.442995
# [129]	valid_0's binary_logloss: 0.441888
# [130]	valid_0's binary_logloss: 0.440795
# [131]	valid_0's binary_logloss: 0.439716
# [132]	valid_0's binary_logloss: 0.438637
# [133]	valid_0's binary_logloss: 0.437573
# [134]	valid_0's binary_logloss: 0.436518
# [135]	valid_0's binary_logloss: 0.435476
# [136]	valid_0's binary_logloss: 0.434435
# [137]	valid_0's binary_logloss: 0.433397
# [138]	valid_0's binary_logloss: 0.432371
# [139]	valid_0's binary_logloss: 0.431361
# [140]	valid_0's binary_logloss: 0.430343
# [141]	valid_0's binary_logloss: 0.429348
# [142]	valid_0's binary_logloss: 0.428352
# [143]	valid_0's binary_logloss: 0.427362
# [144]	valid_0's binary_logloss: 0.426375
# [145]	valid_0's binary_logloss: 0.425403
# [146]	valid_0's binary_logloss: 0.424433
# [147]	valid_0's binary_logloss: 0.423475
# [148]	valid_0's binary_logloss: 0.42252
# [149]	valid_0's binary_logloss: 0.421582
# [150]	valid_0's binary_logloss: 0.420645
# [151]	valid_0's binary_logloss: 0.419713
# [152]	valid_0's binary_logloss: 0.418792
# [153]	valid_0's binary_logloss: 0.417872
# [154]	valid_0's binary_logloss: 0.416956
# [155]	valid_0's binary_logloss: 0.41605
# [156]	valid_0's binary_logloss: 0.415155
# [157]	valid_0's binary_logloss: 0.414261
# [158]	valid_0's binary_logloss: 0.413374
# [159]	valid_0's binary_logloss: 0.412503
# [160]	valid_0's binary_logloss: 0.411625
# [161]	valid_0's binary_logloss: 0.410767
# [162]	valid_0's binary_logloss: 0.40991
# [163]	valid_0's binary_logloss: 0.409057
# [164]	valid_0's binary_logloss: 0.408208
# [165]	valid_0's binary_logloss: 0.407372
# [166]	valid_0's binary_logloss: 0.406535
# [167]	valid_0's binary_logloss: 0.4057
# [168]	valid_0's binary_logloss: 0.404884
# [169]	valid_0's binary_logloss: 0.404072
# [170]	valid_0's binary_logloss: 0.40326
# [171]	valid_0's binary_logloss: 0.40245
# [172]	valid_0's binary_logloss: 0.401659
# [173]	valid_0's binary_logloss: 0.400868
# [174]	valid_0's binary_logloss: 0.400074
# [175]	valid_0's binary_logloss: 0.399295
# [176]	valid_0's binary_logloss: 0.398523
# [177]	valid_0's binary_logloss: 0.397748
# [178]	valid_0's binary_logloss: 0.396982
# [179]	valid_0's binary_logloss: 0.396229
# [180]	valid_0's binary_logloss: 0.395474
# [181]	valid_0's binary_logloss: 0.39473
# [182]	valid_0's binary_logloss: 0.393981
# [183]	valid_0's binary_logloss: 0.393251
# [184]	valid_0's binary_logloss: 0.392524
# [185]	valid_0's binary_logloss: 0.391796
# [186]	valid_0's binary_logloss: 0.391071
# [187]	valid_0's binary_logloss: 0.390357
# [188]	valid_0's binary_logloss: 0.389648
# [189]	valid_0's binary_logloss: 0.388941
# [190]	valid_0's binary_logloss: 0.388237
# [191]	valid_0's binary_logloss: 0.38754
# [192]	valid_0's binary_logloss: 0.386848
# [193]	valid_0's binary_logloss: 0.386161
# [194]	valid_0's binary_logloss: 0.385478
# [195]	valid_0's binary_logloss: 0.384801
# [196]	valid_0's binary_logloss: 0.384132
# [197]	valid_0's binary_logloss: 0.38347
# [198]	valid_0's binary_logloss: 0.382808
# [199]	valid_0's binary_logloss: 0.382153
# [200]	valid_0's binary_logloss: 0.381496
# [201]	valid_0's binary_logloss: 0.380845
# [202]	valid_0's binary_logloss: 0.380205
# [203]	valid_0's binary_logloss: 0.379568
# [204]	valid_0's binary_logloss: 0.378932
# [205]	valid_0's binary_logloss: 0.378303
# [206]	valid_0's binary_logloss: 0.377682
# [207]	valid_0's binary_logloss: 0.377059
# [208]	valid_0's binary_logloss: 0.37644
# [209]	valid_0's binary_logloss: 0.375831
# [210]	valid_0's binary_logloss: 0.375228
# [211]	valid_0's binary_logloss: 0.374625
# [212]	valid_0's binary_logloss: 0.374032
# [213]	valid_0's binary_logloss: 0.373436
# [214]	valid_0's binary_logloss: 0.372848
# [215]	valid_0's binary_logloss: 0.372257
# [216]	valid_0's binary_logloss: 0.371679
# [217]	valid_0's binary_logloss: 0.371099
# [218]	valid_0's binary_logloss: 0.370525
# [219]	valid_0's binary_logloss: 0.369956
# [220]	valid_0's binary_logloss: 0.369391
# [221]	valid_0's binary_logloss: 0.368829
# [222]	valid_0's binary_logloss: 0.368272
# [223]	valid_0's binary_logloss: 0.367716
# [224]	valid_0's binary_logloss: 0.367165
# [225]	valid_0's binary_logloss: 0.36662
# [226]	valid_0's binary_logloss: 0.366073
# [227]	valid_0's binary_logloss: 0.365537
# [228]	valid_0's binary_logloss: 0.365001
# [229]	valid_0's binary_logloss: 0.364463
# [230]	valid_0's binary_logloss: 0.363938
# [231]	valid_0's binary_logloss: 0.363408
# [232]	valid_0's binary_logloss: 0.36289
# [233]	valid_0's binary_logloss: 0.36237
# [234]	valid_0's binary_logloss: 0.361855
# [235]	valid_0's binary_logloss: 0.36134
# [236]	valid_0's binary_logloss: 0.360836
# [237]	valid_0's binary_logloss: 0.360326
# [238]	valid_0's binary_logloss: 0.359827
# [239]	valid_0's binary_logloss: 0.359331
# [240]	valid_0's binary_logloss: 0.358838
# [241]	valid_0's binary_logloss: 0.358351
# [242]	valid_0's binary_logloss: 0.357864
# [243]	valid_0's binary_logloss: 0.357386
# [244]	valid_0's binary_logloss: 0.356907
# [245]	valid_0's binary_logloss: 0.35643
# [246]	valid_0's binary_logloss: 0.355949
# [247]	valid_0's binary_logloss: 0.355475
# [248]	valid_0's binary_logloss: 0.355002
# [249]	valid_0's binary_logloss: 0.354539
# [250]	valid_0's binary_logloss: 0.354072
# [251]	valid_0's binary_logloss: 0.353608
# [252]	valid_0's binary_logloss: 0.353155
# [253]	valid_0's binary_logloss: 0.352702
# [254]	valid_0's binary_logloss: 0.352252
# [255]	valid_0's binary_logloss: 0.351803
# [256]	valid_0's binary_logloss: 0.351363
# [257]	valid_0's binary_logloss: 0.350924
# [258]	valid_0's binary_logloss: 0.350481
# [259]	valid_0's binary_logloss: 0.350046
# [260]	valid_0's binary_logloss: 0.349615
# [261]	valid_0's binary_logloss: 0.349191
# [262]	valid_0's binary_logloss: 0.348765
# [263]	valid_0's binary_logloss: 0.34835
# [264]	valid_0's binary_logloss: 0.347926
# [265]	valid_0's binary_logloss: 0.347513
# [266]	valid_0's binary_logloss: 0.347099
# [267]	valid_0's binary_logloss: 0.346684
# [268]	valid_0's binary_logloss: 0.346269
# [269]	valid_0's binary_logloss: 0.345873
# [270]	valid_0's binary_logloss: 0.345469
# [271]	valid_0's binary_logloss: 0.345065
# [272]	valid_0's binary_logloss: 0.344664
# [273]	valid_0's binary_logloss: 0.344272
# [274]	valid_0's binary_logloss: 0.343881
# [275]	valid_0's binary_logloss: 0.343486
# [276]	valid_0's binary_logloss: 0.343095
# [277]	valid_0's binary_logloss: 0.342711
# [278]	valid_0's binary_logloss: 0.342333
# [279]	valid_0's binary_logloss: 0.341948
# [280]	valid_0's binary_logloss: 0.341575
# [281]	valid_0's binary_logloss: 0.341199
# [282]	valid_0's binary_logloss: 0.340834
# [283]	valid_0's binary_logloss: 0.340457
# [284]	valid_0's binary_logloss: 0.340094
# [285]	valid_0's binary_logloss: 0.339722
# [286]	valid_0's binary_logloss: 0.339352
# [287]	valid_0's binary_logloss: 0.338996
# [288]	valid_0's binary_logloss: 0.338642
# [289]	valid_0's binary_logloss: 0.338291
# [290]	valid_0's binary_logloss: 0.337943
# [291]	valid_0's binary_logloss: 0.337591
# [292]	valid_0's binary_logloss: 0.337246
# [293]	valid_0's binary_logloss: 0.336899
# [294]	valid_0's binary_logloss: 0.336555
# [295]	valid_0's binary_logloss: 0.336213
# [296]	valid_0's binary_logloss: 0.335864
# [297]	valid_0's binary_logloss: 0.335519
# [298]	valid_0's binary_logloss: 0.335175
# [299]	valid_0's binary_logloss: 0.334835
# [300]	valid_0's binary_logloss: 0.334507
# [301]	valid_0's binary_logloss: 0.334181
# [302]	valid_0's binary_logloss: 0.333852
# [303]	valid_0's binary_logloss: 0.333533
# [304]	valid_0's binary_logloss: 0.33321
# [305]	valid_0's binary_logloss: 0.332876
# [306]	valid_0's binary_logloss: 0.332553
# [307]	valid_0's binary_logloss: 0.332234
# [308]	valid_0's binary_logloss: 0.331922
# [309]	valid_0's binary_logloss: 0.331614
# [310]	valid_0's binary_logloss: 0.331309
# [311]	valid_0's binary_logloss: 0.330995
# [312]	valid_0's binary_logloss: 0.330686
# [313]	valid_0's binary_logloss: 0.330375
# [314]	valid_0's binary_logloss: 0.330078
# [315]	valid_0's binary_logloss: 0.329772
# [316]	valid_0's binary_logloss: 0.329468
# [317]	valid_0's binary_logloss: 0.329169
# [318]	valid_0's binary_logloss: 0.328875
# [319]	valid_0's binary_logloss: 0.328574
# [320]	valid_0's binary_logloss: 0.328287
# [321]	valid_0's binary_logloss: 0.328004
# [322]	valid_0's binary_logloss: 0.327709
# [323]	valid_0's binary_logloss: 0.327421
# [324]	valid_0's binary_logloss: 0.327135
# [325]	valid_0's binary_logloss: 0.326849
# [326]	valid_0's binary_logloss: 0.326569
# [327]	valid_0's binary_logloss: 0.326288
# [328]	valid_0's binary_logloss: 0.326012
# [329]	valid_0's binary_logloss: 0.325746
# [330]	valid_0's binary_logloss: 0.325478
# [331]	valid_0's binary_logloss: 0.32521
# [332]	valid_0's binary_logloss: 0.324937
# [333]	valid_0's binary_logloss: 0.324666
# [334]	valid_0's binary_logloss: 0.32439
# [335]	valid_0's binary_logloss: 0.324122
# [336]	valid_0's binary_logloss: 0.32386
# [337]	valid_0's binary_logloss: 0.323584
# [338]	valid_0's binary_logloss: 0.323327
# [339]	valid_0's binary_logloss: 0.323071
# [340]	valid_0's binary_logloss: 0.322808
# [341]	valid_0's binary_logloss: 0.322547
# [342]	valid_0's binary_logloss: 0.322295
# [343]	valid_0's binary_logloss: 0.322041
# [344]	valid_0's binary_logloss: 0.321788
# [345]	valid_0's binary_logloss: 0.321536
# [346]	valid_0's binary_logloss: 0.32129
# [347]	valid_0's binary_logloss: 0.321044
# [348]	valid_0's binary_logloss: 0.320795
# [349]	valid_0's binary_logloss: 0.320551
# [350]	valid_0's binary_logloss: 0.320304
# [351]	valid_0's binary_logloss: 0.320054
# [352]	valid_0's binary_logloss: 0.319815
# [353]	valid_0's binary_logloss: 0.319579
# [354]	valid_0's binary_logloss: 0.319338
# [355]	valid_0's binary_logloss: 0.319099
# [356]	valid_0's binary_logloss: 0.318861
# [357]	valid_0's binary_logloss: 0.318628
# [358]	valid_0's binary_logloss: 0.318384
# [359]	valid_0's binary_logloss: 0.318156
# [360]	valid_0's binary_logloss: 0.317922
# [361]	valid_0's binary_logloss: 0.317694
# [362]	valid_0's binary_logloss: 0.317469
# [363]	valid_0's binary_logloss: 0.317236
# [364]	valid_0's binary_logloss: 0.317007
# [365]	valid_0's binary_logloss: 0.316776
# [366]	valid_0's binary_logloss: 0.316556
# [367]	valid_0's binary_logloss: 0.316339
# [368]	valid_0's binary_logloss: 0.316117
# [369]	valid_0's binary_logloss: 0.315893
# [370]	valid_0's binary_logloss: 0.315665
# [371]	valid_0's binary_logloss: 0.315437
# [372]	valid_0's binary_logloss: 0.315231
# [373]	valid_0's binary_logloss: 0.315025
# [374]	valid_0's binary_logloss: 0.314807
# [375]	valid_0's binary_logloss: 0.314591
# [376]	valid_0's binary_logloss: 0.31439
# [377]	valid_0's binary_logloss: 0.31418
# [378]	valid_0's binary_logloss: 0.313966
# [379]	valid_0's binary_logloss: 0.313757
# [380]	valid_0's binary_logloss: 0.313551
# [381]	valid_0's binary_logloss: 0.313354
# [382]	valid_0's binary_logloss: 0.313144
# [383]	valid_0's binary_logloss: 0.31294
# [384]	valid_0's binary_logloss: 0.312734
# [385]	valid_0's binary_logloss: 0.312528
# [386]	valid_0's binary_logloss: 0.312332
# [387]	valid_0's binary_logloss: 0.312135
# [388]	valid_0's binary_logloss: 0.31194
# [389]	valid_0's binary_logloss: 0.311743
# [390]	valid_0's binary_logloss: 0.311547
# [391]	valid_0's binary_logloss: 0.311343
# [392]	valid_0's binary_logloss: 0.311152
# [393]	valid_0's binary_logloss: 0.310968
# [394]	valid_0's binary_logloss: 0.310765
# [395]	valid_0's binary_logloss: 0.310578
# [396]	valid_0's binary_logloss: 0.31039
# [397]	valid_0's binary_logloss: 0.310204
# [398]	valid_0's binary_logloss: 0.310006
# [399]	valid_0's binary_logloss: 0.309812
# [400]	valid_0's binary_logloss: 0.309627
# [401]	valid_0's binary_logloss: 0.309442
# [402]	valid_0's binary_logloss: 0.30927
# [403]	valid_0's binary_logloss: 0.309084
# [404]	valid_0's binary_logloss: 0.308898
# [405]	valid_0's binary_logloss: 0.308721
# [406]	valid_0's binary_logloss: 0.308545
# [407]	valid_0's binary_logloss: 0.308361
# [408]	valid_0's binary_logloss: 0.308184
# [409]	valid_0's binary_logloss: 0.308011
# [410]	valid_0's binary_logloss: 0.307835
# [411]	valid_0's binary_logloss: 0.307659
# [412]	valid_0's binary_logloss: 0.307484
# [413]	valid_0's binary_logloss: 0.307303
# [414]	valid_0's binary_logloss: 0.307132
# [415]	valid_0's binary_logloss: 0.306969
# [416]	valid_0's binary_logloss: 0.306801
# [417]	valid_0's binary_logloss: 0.306635
# [418]	valid_0's binary_logloss: 0.306466
# [419]	valid_0's binary_logloss: 0.3063
# [420]	valid_0's binary_logloss: 0.306139
# [421]	valid_0's binary_logloss: 0.305978
# [422]	valid_0's binary_logloss: 0.305809
# [423]	valid_0's binary_logloss: 0.305634
# [424]	valid_0's binary_logloss: 0.305475
# [425]	valid_0's binary_logloss: 0.305315
# [426]	valid_0's binary_logloss: 0.305146
# [427]	valid_0's binary_logloss: 0.304987
# [428]	valid_0's binary_logloss: 0.30483
# [429]	valid_0's binary_logloss: 0.304669
# [430]	valid_0's binary_logloss: 0.304512
# [431]	valid_0's binary_logloss: 0.304348
# [432]	valid_0's binary_logloss: 0.304188
# [433]	valid_0's binary_logloss: 0.304033
# [434]	valid_0's binary_logloss: 0.303878
# [435]	valid_0's binary_logloss: 0.303722
# [436]	valid_0's binary_logloss: 0.303567
# [437]	valid_0's binary_logloss: 0.303414
# [438]	valid_0's binary_logloss: 0.303262
# [439]	valid_0's binary_logloss: 0.303106
# [440]	valid_0's binary_logloss: 0.302956
# [441]	valid_0's binary_logloss: 0.302803
# [442]	valid_0's binary_logloss: 0.302661
# [443]	valid_0's binary_logloss: 0.302518
# [444]	valid_0's binary_logloss: 0.302375
# [445]	valid_0's binary_logloss: 0.302224
# [446]	valid_0's binary_logloss: 0.302073
# [447]	valid_0's binary_logloss: 0.301918
# [448]	valid_0's binary_logloss: 0.301774
# [449]	valid_0's binary_logloss: 0.301623
# [450]	valid_0's binary_logloss: 0.301482
# [451]	valid_0's binary_logloss: 0.301339
# [452]	valid_0's binary_logloss: 0.301199
# [453]	valid_0's binary_logloss: 0.301063
# [454]	valid_0's binary_logloss: 0.300923
# [455]	valid_0's binary_logloss: 0.300772
# [456]	valid_0's binary_logloss: 0.30063
# [457]	valid_0's binary_logloss: 0.300487
# [458]	valid_0's binary_logloss: 0.300352
# [459]	valid_0's binary_logloss: 0.300211
# [460]	valid_0's binary_logloss: 0.300077
# [461]	valid_0's binary_logloss: 0.299952
# [462]	valid_0's binary_logloss: 0.29982
# [463]	valid_0's binary_logloss: 0.299678
# [464]	valid_0's binary_logloss: 0.299549
# [465]	valid_0's binary_logloss: 0.299422
# [466]	valid_0's binary_logloss: 0.29928
# [467]	valid_0's binary_logloss: 0.299142
# [468]	valid_0's binary_logloss: 0.299016
# [469]	valid_0's binary_logloss: 0.298884
# [470]	valid_0's binary_logloss: 0.298748
# [471]	valid_0's binary_logloss: 0.298622
# [472]	valid_0's binary_logloss: 0.298498
# [473]	valid_0's binary_logloss: 0.298367
# [474]	valid_0's binary_logloss: 0.298228
# [475]	valid_0's binary_logloss: 0.298097
# [476]	valid_0's binary_logloss: 0.297971
# [477]	valid_0's binary_logloss: 0.297842
# [478]	valid_0's binary_logloss: 0.297719
# [479]	valid_0's binary_logloss: 0.297586
# [480]	valid_0's binary_logloss: 0.297463
# [481]	valid_0's binary_logloss: 0.297346
# [482]	valid_0's binary_logloss: 0.297222
# [483]	valid_0's binary_logloss: 0.297093
# [484]	valid_0's binary_logloss: 0.29697
# [485]	valid_0's binary_logloss: 0.296843
# [486]	valid_0's binary_logloss: 0.296714
# [487]	valid_0's binary_logloss: 0.2966
# [488]	valid_0's binary_logloss: 0.296488
# [489]	valid_0's binary_logloss: 0.296368
# [490]	valid_0's binary_logloss: 0.296248
# [491]	valid_0's binary_logloss: 0.296134
# [492]	valid_0's binary_logloss: 0.296024
# [493]	valid_0's binary_logloss: 0.295896
# [494]	valid_0's binary_logloss: 0.295763
# [495]	valid_0's binary_logloss: 0.295641
# [496]	valid_0's binary_logloss: 0.295518
# [497]	valid_0's binary_logloss: 0.295403
# [498]	valid_0's binary_logloss: 0.295291
# [499]	valid_0's binary_logloss: 0.295169
# [500]	valid_0's binary_logloss: 0.295058
# [501]	valid_0's binary_logloss: 0.294949
# [502]	valid_0's binary_logloss: 0.294826
# [503]	valid_0's binary_logloss: 0.294713
# [504]	valid_0's binary_logloss: 0.294604
# [505]	valid_0's binary_logloss: 0.29448
# [506]	valid_0's binary_logloss: 0.294364
# [507]	valid_0's binary_logloss: 0.294245
# [508]	valid_0's binary_logloss: 0.294133
# [509]	valid_0's binary_logloss: 0.294011
# [510]	valid_0's binary_logloss: 0.293902
# [511]	valid_0's binary_logloss: 0.293791
# [512]	valid_0's binary_logloss: 0.293678
# [513]	valid_0's binary_logloss: 0.293569
# [514]	valid_0's binary_logloss: 0.293453
# [515]	valid_0's binary_logloss: 0.293348
# [516]	valid_0's binary_logloss: 0.293231
# [517]	valid_0's binary_logloss: 0.293126
# [518]	valid_0's binary_logloss: 0.293021
# [519]	valid_0's binary_logloss: 0.292907
# [520]	valid_0's binary_logloss: 0.292799
# [521]	valid_0's binary_logloss: 0.292698
# [522]	valid_0's binary_logloss: 0.292586
# [523]	valid_0's binary_logloss: 0.292481
# [524]	valid_0's binary_logloss: 0.292374
# [525]	valid_0's binary_logloss: 0.292258
# [526]	valid_0's binary_logloss: 0.292146
# [527]	valid_0's binary_logloss: 0.292044
# [528]	valid_0's binary_logloss: 0.291941
# [529]	valid_0's binary_logloss: 0.291838
# [530]	valid_0's binary_logloss: 0.291737
# [531]	valid_0's binary_logloss: 0.291632
# [532]	valid_0's binary_logloss: 0.291519
# [533]	valid_0's binary_logloss: 0.291413
# [534]	valid_0's binary_logloss: 0.291314
# [535]	valid_0's binary_logloss: 0.291219
# [536]	valid_0's binary_logloss: 0.291123
# [537]	valid_0's binary_logloss: 0.291021
# [538]	valid_0's binary_logloss: 0.290915
# [539]	valid_0's binary_logloss: 0.290807
# [540]	valid_0's binary_logloss: 0.290714
# [541]	valid_0's binary_logloss: 0.290602
# [542]	valid_0's binary_logloss: 0.290512
# [543]	valid_0's binary_logloss: 0.290419
# [544]	valid_0's binary_logloss: 0.290326
# [545]	valid_0's binary_logloss: 0.290229
# [546]	valid_0's binary_logloss: 0.290142
# [547]	valid_0's binary_logloss: 0.290039
# [548]	valid_0's binary_logloss: 0.28993
# [549]	valid_0's binary_logloss: 0.289841
# [550]	valid_0's binary_logloss: 0.289734
# [551]	valid_0's binary_logloss: 0.289625
# [552]	valid_0's binary_logloss: 0.28952
# [553]	valid_0's binary_logloss: 0.289432
# [554]	valid_0's binary_logloss: 0.289326
# [555]	valid_0's binary_logloss: 0.289218
# [556]	valid_0's binary_logloss: 0.289121
# [557]	valid_0's binary_logloss: 0.289027
# [558]	valid_0's binary_logloss: 0.288929
# [559]	valid_0's binary_logloss: 0.288835
# [560]	valid_0's binary_logloss: 0.288748
# [561]	valid_0's binary_logloss: 0.288656
# [562]	valid_0's binary_logloss: 0.288566
# [563]	valid_0's binary_logloss: 0.288482
# [564]	valid_0's binary_logloss: 0.288387
# [565]	valid_0's binary_logloss: 0.288304
# [566]	valid_0's binary_logloss: 0.288208
# [567]	valid_0's binary_logloss: 0.288101
# [568]	valid_0's binary_logloss: 0.288013
# [569]	valid_0's binary_logloss: 0.287928
# [570]	valid_0's binary_logloss: 0.28783
# [571]	valid_0's binary_logloss: 0.287734
# [572]	valid_0's binary_logloss: 0.287644
# [573]	valid_0's binary_logloss: 0.287566
# [574]	valid_0's binary_logloss: 0.287471
# [575]	valid_0's binary_logloss: 0.287388
# [576]	valid_0's binary_logloss: 0.287295
# [577]	valid_0's binary_logloss: 0.287203
# [578]	valid_0's binary_logloss: 0.287118
# [579]	valid_0's binary_logloss: 0.287023
# [580]	valid_0's binary_logloss: 0.286932
# [581]	valid_0's binary_logloss: 0.286845
# [582]	valid_0's binary_logloss: 0.286764
# [583]	valid_0's binary_logloss: 0.286683
# [584]	valid_0's binary_logloss: 0.286592
# [585]	valid_0's binary_logloss: 0.286506
# [586]	valid_0's binary_logloss: 0.286423
# [587]	valid_0's binary_logloss: 0.286331
# [588]	valid_0's binary_logloss: 0.28625
# [589]	valid_0's binary_logloss: 0.286151
# [590]	valid_0's binary_logloss: 0.286061
# [591]	valid_0's binary_logloss: 0.285975
# [592]	valid_0's binary_logloss: 0.285881
# [593]	valid_0's binary_logloss: 0.285791
# [594]	valid_0's binary_logloss: 0.285699
# [595]	valid_0's binary_logloss: 0.285614
# [596]	valid_0's binary_logloss: 0.28554
# [597]	valid_0's binary_logloss: 0.285447
# [598]	valid_0's binary_logloss: 0.285371
# [599]	valid_0's binary_logloss: 0.285279
# [600]	valid_0's binary_logloss: 0.285199
# [601]	valid_0's binary_logloss: 0.285118
# [602]	valid_0's binary_logloss: 0.285038
# [603]	valid_0's binary_logloss: 0.284947
# [604]	valid_0's binary_logloss: 0.284854
# [605]	valid_0's binary_logloss: 0.284758
# [606]	valid_0's binary_logloss: 0.284676
# [607]	valid_0's binary_logloss: 0.284584
# [608]	valid_0's binary_logloss: 0.284506
# [609]	valid_0's binary_logloss: 0.284421
# [610]	valid_0's binary_logloss: 0.284344
# [611]	valid_0's binary_logloss: 0.28427
# [612]	valid_0's binary_logloss: 0.284196
# [613]	valid_0's binary_logloss: 0.284115
# [614]	valid_0's binary_logloss: 0.284029
# [615]	valid_0's binary_logloss: 0.283938
# [616]	valid_0's binary_logloss: 0.283868
# [617]	valid_0's binary_logloss: 0.283782
# [618]	valid_0's binary_logloss: 0.283701
# [619]	valid_0's binary_logloss: 0.283609
# [620]	valid_0's binary_logloss: 0.283536
# [621]	valid_0's binary_logloss: 0.283457
# [622]	valid_0's binary_logloss: 0.283372
# [623]	valid_0's binary_logloss: 0.283297
# [624]	valid_0's binary_logloss: 0.283215
# [625]	valid_0's binary_logloss: 0.283146
# [626]	valid_0's binary_logloss: 0.28306
# [627]	valid_0's binary_logloss: 0.282986
# [628]	valid_0's binary_logloss: 0.282916
# [629]	valid_0's binary_logloss: 0.282835
# [630]	valid_0's binary_logloss: 0.28276
# [631]	valid_0's binary_logloss: 0.282688
# [632]	valid_0's binary_logloss: 0.282618
# [633]	valid_0's binary_logloss: 0.282535
# [634]	valid_0's binary_logloss: 0.282457
# [635]	valid_0's binary_logloss: 0.282381
# [636]	valid_0's binary_logloss: 0.282306
# [637]	valid_0's binary_logloss: 0.282219
# [638]	valid_0's binary_logloss: 0.282138
# [639]	valid_0's binary_logloss: 0.282056
# [640]	valid_0's binary_logloss: 0.281982
# [641]	valid_0's binary_logloss: 0.281908
# [642]	valid_0's binary_logloss: 0.281836
# [643]	valid_0's binary_logloss: 0.281755
# [644]	valid_0's binary_logloss: 0.281686
# [645]	valid_0's binary_logloss: 0.281614
# [646]	valid_0's binary_logloss: 0.281531
# [647]	valid_0's binary_logloss: 0.281444
# [648]	valid_0's binary_logloss: 0.281366
# [649]	valid_0's binary_logloss: 0.281294
# [650]	valid_0's binary_logloss: 0.281225
# [651]	valid_0's binary_logloss: 0.281144
# [652]	valid_0's binary_logloss: 0.281069
# [653]	valid_0's binary_logloss: 0.281004
# [654]	valid_0's binary_logloss: 0.280938
# [655]	valid_0's binary_logloss: 0.280862
# [656]	valid_0's binary_logloss: 0.280783
# [657]	valid_0's binary_logloss: 0.28071
# [658]	valid_0's binary_logloss: 0.280642
# [659]	valid_0's binary_logloss: 0.280561
# [660]	valid_0's binary_logloss: 0.280495
# [661]	valid_0's binary_logloss: 0.280425
# [662]	valid_0's binary_logloss: 0.280353
# [663]	valid_0's binary_logloss: 0.280276
# [664]	valid_0's binary_logloss: 0.280197
# [665]	valid_0's binary_logloss: 0.280133
# [666]	valid_0's binary_logloss: 0.280061
# [667]	valid_0's binary_logloss: 0.279987
# [668]	valid_0's binary_logloss: 0.279907
# [669]	valid_0's binary_logloss: 0.279834
# [670]	valid_0's binary_logloss: 0.279756
# [671]	valid_0's binary_logloss: 0.279679
# [672]	valid_0's binary_logloss: 0.279616
# [673]	valid_0's binary_logloss: 0.279539
# [674]	valid_0's binary_logloss: 0.279467
# [675]	valid_0's binary_logloss: 0.279408
# [676]	valid_0's binary_logloss: 0.279327
# [677]	valid_0's binary_logloss: 0.279252
# [678]	valid_0's binary_logloss: 0.279178
# [679]	valid_0's binary_logloss: 0.279106
# [680]	valid_0's binary_logloss: 0.279037
# [681]	valid_0's binary_logloss: 0.278968
# [682]	valid_0's binary_logloss: 0.278897
# [683]	valid_0's binary_logloss: 0.278823
# [684]	valid_0's binary_logloss: 0.278749
# [685]	valid_0's binary_logloss: 0.278684
# [686]	valid_0's binary_logloss: 0.278619
# [687]	valid_0's binary_logloss: 0.278559
# [688]	valid_0's binary_logloss: 0.278484
# [689]	valid_0's binary_logloss: 0.278407
# [690]	valid_0's binary_logloss: 0.27833
# [691]	valid_0's binary_logloss: 0.278258
# [692]	valid_0's binary_logloss: 0.278187
# [693]	valid_0's binary_logloss: 0.278116
# [694]	valid_0's binary_logloss: 0.278054
# [695]	valid_0's binary_logloss: 0.277983
# [696]	valid_0's binary_logloss: 0.277916
# [697]	valid_0's binary_logloss: 0.277839
# [698]	valid_0's binary_logloss: 0.277777
# [699]	valid_0's binary_logloss: 0.277701
# [700]	valid_0's binary_logloss: 0.277641
# [701]	valid_0's binary_logloss: 0.277573
# [702]	valid_0's binary_logloss: 0.2775
# [703]	valid_0's binary_logloss: 0.277432
# [704]	valid_0's binary_logloss: 0.277365
# [705]	valid_0's binary_logloss: 0.2773
# [706]	valid_0's binary_logloss: 0.277228
# [707]	valid_0's binary_logloss: 0.277169
# [708]	valid_0's binary_logloss: 0.277108
# [709]	valid_0's binary_logloss: 0.27704
# [710]	valid_0's binary_logloss: 0.276955
# [711]	valid_0's binary_logloss: 0.276887
# [712]	valid_0's binary_logloss: 0.276828
# [713]	valid_0's binary_logloss: 0.276766
# [714]	valid_0's binary_logloss: 0.276695
# [715]	valid_0's binary_logloss: 0.276635
# [716]	valid_0's binary_logloss: 0.276563
# [717]	valid_0's binary_logloss: 0.276496
# [718]	valid_0's binary_logloss: 0.276424
# [719]	valid_0's binary_logloss: 0.276351
# [720]	valid_0's binary_logloss: 0.276291
# [721]	valid_0's binary_logloss: 0.276225
# [722]	valid_0's binary_logloss: 0.276159
# [723]	valid_0's binary_logloss: 0.276097
# [724]	valid_0's binary_logloss: 0.276039
# [725]	valid_0's binary_logloss: 0.275972
# [726]	valid_0's binary_logloss: 0.275913
# [727]	valid_0's binary_logloss: 0.275842
# [728]	valid_0's binary_logloss: 0.275773
# [729]	valid_0's binary_logloss: 0.275708
# [730]	valid_0's binary_logloss: 0.275625
# [731]	valid_0's binary_logloss: 0.275558
# [732]	valid_0's binary_logloss: 0.275501
# [733]	valid_0's binary_logloss: 0.275435
# [734]	valid_0's binary_logloss: 0.275374
# [735]	valid_0's binary_logloss: 0.275316
# [736]	valid_0's binary_logloss: 0.275248
# [737]	valid_0's binary_logloss: 0.275181
# [738]	valid_0's binary_logloss: 0.275128
# [739]	valid_0's binary_logloss: 0.275072
# [740]	valid_0's binary_logloss: 0.275006
# [741]	valid_0's binary_logloss: 0.27494
# [742]	valid_0's binary_logloss: 0.274869
# [743]	valid_0's binary_logloss: 0.274805
# [744]	valid_0's binary_logloss: 0.274739
# [745]	valid_0's binary_logloss: 0.274674
# [746]	valid_0's binary_logloss: 0.274618
# [747]	valid_0's binary_logloss: 0.27456
# [748]	valid_0's binary_logloss: 0.274496
# [749]	valid_0's binary_logloss: 0.274443
# [750]	valid_0's binary_logloss: 0.274373
# [751]	valid_0's binary_logloss: 0.274311
# [752]	valid_0's binary_logloss: 0.274241
# [753]	valid_0's binary_logloss: 0.274183
# [754]	valid_0's binary_logloss: 0.27412
# [755]	valid_0's binary_logloss: 0.274063
# [756]	valid_0's binary_logloss: 0.273991
# [757]	valid_0's binary_logloss: 0.273929
# [758]	valid_0's binary_logloss: 0.273869
# [759]	valid_0's binary_logloss: 0.273798
# [760]	valid_0's binary_logloss: 0.273736
# [761]	valid_0's binary_logloss: 0.273679
# [762]	valid_0's binary_logloss: 0.273614
# [763]	valid_0's binary_logloss: 0.273563
# [764]	valid_0's binary_logloss: 0.273499
# [765]	valid_0's binary_logloss: 0.273427
# [766]	valid_0's binary_logloss: 0.27336
# [767]	valid_0's binary_logloss: 0.273293
# [768]	valid_0's binary_logloss: 0.273237
# [769]	valid_0's binary_logloss: 0.273174
# [770]	valid_0's binary_logloss: 0.273111
# [771]	valid_0's binary_logloss: 0.273048
# [772]	valid_0's binary_logloss: 0.272982
# [773]	valid_0's binary_logloss: 0.272925
# [774]	valid_0's binary_logloss: 0.272876
# [775]	valid_0's binary_logloss: 0.27281
# [776]	valid_0's binary_logloss: 0.272748
# [777]	valid_0's binary_logloss: 0.272686
# [778]	valid_0's binary_logloss: 0.27262
# [779]	valid_0's binary_logloss: 0.272566
# [780]	valid_0's binary_logloss: 0.272505
# [781]	valid_0's binary_logloss: 0.272442
# [782]	valid_0's binary_logloss: 0.272392
# [783]	valid_0's binary_logloss: 0.27233
# [784]	valid_0's binary_logloss: 0.272268
# [785]	valid_0's binary_logloss: 0.272213
# [786]	valid_0's binary_logloss: 0.272151
# [787]	valid_0's binary_logloss: 0.27209
# [788]	valid_0's binary_logloss: 0.272029
# [789]	valid_0's binary_logloss: 0.27197
# [790]	valid_0's binary_logloss: 0.271907
# [791]	valid_0's binary_logloss: 0.27184
# [792]	valid_0's binary_logloss: 0.271775
# [793]	valid_0's binary_logloss: 0.271722
# [794]	valid_0's binary_logloss: 0.27165
# [795]	valid_0's binary_logloss: 0.271601
# [796]	valid_0's binary_logloss: 0.271532
# [797]	valid_0's binary_logloss: 0.271472
# [798]	valid_0's binary_logloss: 0.271416
# [799]	valid_0's binary_logloss: 0.271359
# [800]	valid_0's binary_logloss: 0.271298
# [801]	valid_0's binary_logloss: 0.271238
# [802]	valid_0's binary_logloss: 0.271185
# [803]	valid_0's binary_logloss: 0.271131
# [804]	valid_0's binary_logloss: 0.27107
# [805]	valid_0's binary_logloss: 0.271013
# [806]	valid_0's binary_logloss: 0.270951
# [807]	valid_0's binary_logloss: 0.270889
# [808]	valid_0's binary_logloss: 0.270836
# [809]	valid_0's binary_logloss: 0.270776
# [810]	valid_0's binary_logloss: 0.270713
# [811]	valid_0's binary_logloss: 0.270659
# [812]	valid_0's binary_logloss: 0.270609
# [813]	valid_0's binary_logloss: 0.270556
# [814]	valid_0's binary_logloss: 0.270494
# [815]	valid_0's binary_logloss: 0.270434
# [816]	valid_0's binary_logloss: 0.270374
# [817]	valid_0's binary_logloss: 0.270317
# [818]	valid_0's binary_logloss: 0.270262
# [819]	valid_0's binary_logloss: 0.270207
# [820]	valid_0's binary_logloss: 0.270158
# [821]	valid_0's binary_logloss: 0.2701
# [822]	valid_0's binary_logloss: 0.270039
# [823]	valid_0's binary_logloss: 0.269978
# [824]	valid_0's binary_logloss: 0.269926
# [825]	valid_0's binary_logloss: 0.269865
# [826]	valid_0's binary_logloss: 0.26981
# [827]	valid_0's binary_logloss: 0.269746
# [828]	valid_0's binary_logloss: 0.269684
# [829]	valid_0's binary_logloss: 0.269628
# [830]	valid_0's binary_logloss: 0.269574
# [831]	valid_0's binary_logloss: 0.26952
# [832]	valid_0's binary_logloss: 0.26947
# [833]	valid_0's binary_logloss: 0.269417
# [834]	valid_0's binary_logloss: 0.269359
# [835]	valid_0's binary_logloss: 0.269307
# [836]	valid_0's binary_logloss: 0.269249
# [837]	valid_0's binary_logloss: 0.269199
# [838]	valid_0's binary_logloss: 0.269139
# [839]	valid_0's binary_logloss: 0.26908
# [840]	valid_0's binary_logloss: 0.269029
# [841]	valid_0's binary_logloss: 0.268981
# [842]	valid_0's binary_logloss: 0.268932
# [843]	valid_0's binary_logloss: 0.268873
# [844]	valid_0's binary_logloss: 0.268815
# [845]	valid_0's binary_logloss: 0.268764
# [846]	valid_0's binary_logloss: 0.268707
# [847]	valid_0's binary_logloss: 0.26866
# [848]	valid_0's binary_logloss: 0.268608
# [849]	valid_0's binary_logloss: 0.268551
# [850]	valid_0's binary_logloss: 0.268502
# [851]	valid_0's binary_logloss: 0.268441
# [852]	valid_0's binary_logloss: 0.268387
# [853]	valid_0's binary_logloss: 0.268336
# [854]	valid_0's binary_logloss: 0.268284
# [855]	valid_0's binary_logloss: 0.268221
# [856]	valid_0's binary_logloss: 0.268164
# [857]	valid_0's binary_logloss: 0.268115
# [858]	valid_0's binary_logloss: 0.268059
# [859]	valid_0's binary_logloss: 0.268008
# [860]	valid_0's binary_logloss: 0.267958
# [861]	valid_0's binary_logloss: 0.267905
# [862]	valid_0's binary_logloss: 0.267848
# [863]	valid_0's binary_logloss: 0.267793
# [864]	valid_0's binary_logloss: 0.267738
# [865]	valid_0's binary_logloss: 0.267685
# [866]	valid_0's binary_logloss: 0.267637
# [867]	valid_0's binary_logloss: 0.267585
# [868]	valid_0's binary_logloss: 0.267535
# [869]	valid_0's binary_logloss: 0.26749
# [870]	valid_0's binary_logloss: 0.267432
# [871]	valid_0's binary_logloss: 0.26738
# [872]	valid_0's binary_logloss: 0.267326
# [873]	valid_0's binary_logloss: 0.267275
# [874]	valid_0's binary_logloss: 0.267224
# [875]	valid_0's binary_logloss: 0.267165
# [876]	valid_0's binary_logloss: 0.267113
# [877]	valid_0's binary_logloss: 0.267058
# [878]	valid_0's binary_logloss: 0.267002
# [879]	valid_0's binary_logloss: 0.26695
# [880]	valid_0's binary_logloss: 0.266906
# [881]	valid_0's binary_logloss: 0.26686
# [882]	valid_0's binary_logloss: 0.266809
# [883]	valid_0's binary_logloss: 0.266761
# [884]	valid_0's binary_logloss: 0.266714
# [885]	valid_0's binary_logloss: 0.266667
# [886]	valid_0's binary_logloss: 0.266609
# [887]	valid_0's binary_logloss: 0.266565
# [888]	valid_0's binary_logloss: 0.266511
# [889]	valid_0's binary_logloss: 0.266456
# [890]	valid_0's binary_logloss: 0.266411
# [891]	valid_0's binary_logloss: 0.266361
# [892]	valid_0's binary_logloss: 0.266309
# [893]	valid_0's binary_logloss: 0.266259
# [894]	valid_0's binary_logloss: 0.266212
# [895]	valid_0's binary_logloss: 0.266155
# [896]	valid_0's binary_logloss: 0.266105
# [897]	valid_0's binary_logloss: 0.266051
# [898]	valid_0's binary_logloss: 0.265995
# [899]	valid_0's binary_logloss: 0.265949
# [900]	valid_0's binary_logloss: 0.2659
# [901]	valid_0's binary_logloss: 0.26584
# [902]	valid_0's binary_logloss: 0.26579
# [903]	valid_0's binary_logloss: 0.265741
# [904]	valid_0's binary_logloss: 0.265696
# [905]	valid_0's binary_logloss: 0.265635
# [906]	valid_0's binary_logloss: 0.265582
# [907]	valid_0's binary_logloss: 0.265536
# [908]	valid_0's binary_logloss: 0.265493
# [909]	valid_0's binary_logloss: 0.265443
# [910]	valid_0's binary_logloss: 0.265393
# [911]	valid_0's binary_logloss: 0.265344
# [912]	valid_0's binary_logloss: 0.265294
# [913]	valid_0's binary_logloss: 0.265243
# [914]	valid_0's binary_logloss: 0.265194
# [915]	valid_0's binary_logloss: 0.265142
# [916]	valid_0's binary_logloss: 0.265088
# [917]	valid_0's binary_logloss: 0.265037
# [918]	valid_0's binary_logloss: 0.264998
# [919]	valid_0's binary_logloss: 0.264948
# [920]	valid_0's binary_logloss: 0.264901
# [921]	valid_0's binary_logloss: 0.264851
# [922]	valid_0's binary_logloss: 0.264795
# [923]	valid_0's binary_logloss: 0.264745
# [924]	valid_0's binary_logloss: 0.264699
# [925]	valid_0's binary_logloss: 0.264646
# [926]	valid_0's binary_logloss: 0.264603
# [927]	valid_0's binary_logloss: 0.264553
# [928]	valid_0's binary_logloss: 0.264508
# [929]	valid_0's binary_logloss: 0.264463
# [930]	valid_0's binary_logloss: 0.264413
# [931]	valid_0's binary_logloss: 0.264362
# [932]	valid_0's binary_logloss: 0.264313
# [933]	valid_0's binary_logloss: 0.264263
# [934]	valid_0's binary_logloss: 0.26422
# [935]	valid_0's binary_logloss: 0.264176
# [936]	valid_0's binary_logloss: 0.264122
# [937]	valid_0's binary_logloss: 0.264077
# [938]	valid_0's binary_logloss: 0.264032
# [939]	valid_0's binary_logloss: 0.26399
# [940]	valid_0's binary_logloss: 0.263943
# [941]	valid_0's binary_logloss: 0.263899
# [942]	valid_0's binary_logloss: 0.263851
# [943]	valid_0's binary_logloss: 0.263808
# [944]	valid_0's binary_logloss: 0.263752
# [945]	valid_0's binary_logloss: 0.263703
# [946]	valid_0's binary_logloss: 0.263654
# [947]	valid_0's binary_logloss: 0.263606
# [948]	valid_0's binary_logloss: 0.263555
# [949]	valid_0's binary_logloss: 0.263508
# [950]	valid_0's binary_logloss: 0.263467
# [951]	valid_0's binary_logloss: 0.263415
# [952]	valid_0's binary_logloss: 0.263367
# [953]	valid_0's binary_logloss: 0.263331
# [954]	valid_0's binary_logloss: 0.26328
# [955]	valid_0's binary_logloss: 0.263229
# [956]	valid_0's binary_logloss: 0.263188
# [957]	valid_0's binary_logloss: 0.26314
# [958]	valid_0's binary_logloss: 0.263089
# [959]	valid_0's binary_logloss: 0.263035
# [960]	valid_0's binary_logloss: 0.262988
# [961]	valid_0's binary_logloss: 0.262943
# [962]	valid_0's binary_logloss: 0.262899
# [963]	valid_0's binary_logloss: 0.262845
# [964]	valid_0's binary_logloss: 0.2628
# [965]	valid_0's binary_logloss: 0.262749
# [966]	valid_0's binary_logloss: 0.262709
# [967]	valid_0's binary_logloss: 0.262661
# [968]	valid_0's binary_logloss: 0.262623
# [969]	valid_0's binary_logloss: 0.262572
# [970]	valid_0's binary_logloss: 0.262526
# [971]	valid_0's binary_logloss: 0.262481
# [972]	valid_0's binary_logloss: 0.262438
# [973]	valid_0's binary_logloss: 0.262388
# [974]	valid_0's binary_logloss: 0.26234
# [975]	valid_0's binary_logloss: 0.262287
# [976]	valid_0's binary_logloss: 0.26224
# [977]	valid_0's binary_logloss: 0.262195
# [978]	valid_0's binary_logloss: 0.262145
# [979]	valid_0's binary_logloss: 0.262104
# [980]	valid_0's binary_logloss: 0.262064
# [981]	valid_0's binary_logloss: 0.262026
# [982]	valid_0's binary_logloss: 0.261984
# [983]	valid_0's binary_logloss: 0.26194
# [984]	valid_0's binary_logloss: 0.261891
# [985]	valid_0's binary_logloss: 0.261847
# [986]	valid_0's binary_logloss: 0.261801
# [987]	valid_0's binary_logloss: 0.261751
# [988]	valid_0's binary_logloss: 0.261699
# [989]	valid_0's binary_logloss: 0.261659
# [990]	valid_0's binary_logloss: 0.261608
# [991]	valid_0's binary_logloss: 0.261563
# [992]	valid_0's binary_logloss: 0.261519
# [993]	valid_0's binary_logloss: 0.261474
# [994]	valid_0's binary_logloss: 0.261426
# [995]	valid_0's binary_logloss: 0.26138
# [996]	valid_0's binary_logloss: 0.261339
# [997]	valid_0's binary_logloss: 0.261294
# [998]	valid_0's binary_logloss: 0.261252
# [999]	valid_0's binary_logloss: 0.261206
# [1000]	valid_0's binary_logloss: 0.261166
# [1001]	valid_0's binary_logloss: 0.261125
# [1002]	valid_0's binary_logloss: 0.261076
# [1003]	valid_0's binary_logloss: 0.261033
# [1004]	valid_0's binary_logloss: 0.260982
# [1005]	valid_0's binary_logloss: 0.260938
# [1006]	valid_0's binary_logloss: 0.260892
# [1007]	valid_0's binary_logloss: 0.260853
# [1008]	valid_0's binary_logloss: 0.260801
# [1009]	valid_0's binary_logloss: 0.260757
# [1010]	valid_0's binary_logloss: 0.260714
# [1011]	valid_0's binary_logloss: 0.260678
# [1012]	valid_0's binary_logloss: 0.260635
# [1013]	valid_0's binary_logloss: 0.260596
# [1014]	valid_0's binary_logloss: 0.260551
# [1015]	valid_0's binary_logloss: 0.26051
# [1016]	valid_0's binary_logloss: 0.260471
# [1017]	valid_0's binary_logloss: 0.260429
# [1018]	valid_0's binary_logloss: 0.260383
# [1019]	valid_0's binary_logloss: 0.260326
# [1020]	valid_0's binary_logloss: 0.260287
# [1021]	valid_0's binary_logloss: 0.260242
# [1022]	valid_0's binary_logloss: 0.2602
# [1023]	valid_0's binary_logloss: 0.260158
# [1024]	valid_0's binary_logloss: 0.260112
# [1025]	valid_0's binary_logloss: 0.260068
# [1026]	valid_0's binary_logloss: 0.260025
# [1027]	valid_0's binary_logloss: 0.259981
# [1028]	valid_0's binary_logloss: 0.259939
# [1029]	valid_0's binary_logloss: 0.259899
# [1030]	valid_0's binary_logloss: 0.259862
# [1031]	valid_0's binary_logloss: 0.259819
# [1032]	valid_0's binary_logloss: 0.259772
# [1033]	valid_0's binary_logloss: 0.259731
# [1034]	valid_0's binary_logloss: 0.259679
# [1035]	valid_0's binary_logloss: 0.259639
# [1036]	valid_0's binary_logloss: 0.259597
# [1037]	valid_0's binary_logloss: 0.259549
# [1038]	valid_0's binary_logloss: 0.259506
# [1039]	valid_0's binary_logloss: 0.259461
# [1040]	valid_0's binary_logloss: 0.259413
# [1041]	valid_0's binary_logloss: 0.259366
# [1042]	valid_0's binary_logloss: 0.259327
# [1043]	valid_0's binary_logloss: 0.259282
# [1044]	valid_0's binary_logloss: 0.259241
# [1045]	valid_0's binary_logloss: 0.259202
# [1046]	valid_0's binary_logloss: 0.259163
# [1047]	valid_0's binary_logloss: 0.259124
# [1048]	valid_0's binary_logloss: 0.259087
# [1049]	valid_0's binary_logloss: 0.259049
# [1050]	valid_0's binary_logloss: 0.259006
# [1051]	valid_0's binary_logloss: 0.258965
# [1052]	valid_0's binary_logloss: 0.258928
# [1053]	valid_0's binary_logloss: 0.258882
# [1054]	valid_0's binary_logloss: 0.258838
# [1055]	valid_0's binary_logloss: 0.258794
# [1056]	valid_0's binary_logloss: 0.258755
# [1057]	valid_0's binary_logloss: 0.25872
# [1058]	valid_0's binary_logloss: 0.258679
# [1059]	valid_0's binary_logloss: 0.258636
# [1060]	valid_0's binary_logloss: 0.258594
# [1061]	valid_0's binary_logloss: 0.25855
# [1062]	valid_0's binary_logloss: 0.258512
# [1063]	valid_0's binary_logloss: 0.25847
# [1064]	valid_0's binary_logloss: 0.258426
# [1065]	valid_0's binary_logloss: 0.258385
# [1066]	valid_0's binary_logloss: 0.258344
# [1067]	valid_0's binary_logloss: 0.258304
# [1068]	valid_0's binary_logloss: 0.258261
# [1069]	valid_0's binary_logloss: 0.258221
# [1070]	valid_0's binary_logloss: 0.258178
# [1071]	valid_0's binary_logloss: 0.25814
# [1072]	valid_0's binary_logloss: 0.258096
# [1073]	valid_0's binary_logloss: 0.258065
# [1074]	valid_0's binary_logloss: 0.258024
# [1075]	valid_0's binary_logloss: 0.257986
# [1076]	valid_0's binary_logloss: 0.257943
# [1077]	valid_0's binary_logloss: 0.257903
# [1078]	valid_0's binary_logloss: 0.257866
# [1079]	valid_0's binary_logloss: 0.257823
# [1080]	valid_0's binary_logloss: 0.257784
# [1081]	valid_0's binary_logloss: 0.257734
# [1082]	valid_0's binary_logloss: 0.257689
# [1083]	valid_0's binary_logloss: 0.257651
# [1084]	valid_0's binary_logloss: 0.25761
# [1085]	valid_0's binary_logloss: 0.257573
# [1086]	valid_0's binary_logloss: 0.257539
# [1087]	valid_0's binary_logloss: 0.257501
# [1088]	valid_0's binary_logloss: 0.257459
# [1089]	valid_0's binary_logloss: 0.257417
# [1090]	valid_0's binary_logloss: 0.257377
# [1091]	valid_0's binary_logloss: 0.257343
# [1092]	valid_0's binary_logloss: 0.257305
# [1093]	valid_0's binary_logloss: 0.257268
# [1094]	valid_0's binary_logloss: 0.257223
# [1095]	valid_0's binary_logloss: 0.257189
# [1096]	valid_0's binary_logloss: 0.257144
# [1097]	valid_0's binary_logloss: 0.257098
# [1098]	valid_0's binary_logloss: 0.257059
# [1099]	valid_0's binary_logloss: 0.257022
# [1100]	valid_0's binary_logloss: 0.256975
# [1101]	valid_0's binary_logloss: 0.256929
# [1102]	valid_0's binary_logloss: 0.256894
# [1103]	valid_0's binary_logloss: 0.256853
# [1104]	valid_0's binary_logloss: 0.256823
# [1105]	valid_0's binary_logloss: 0.256787
# [1106]	valid_0's binary_logloss: 0.256753
# [1107]	valid_0's binary_logloss: 0.256719
# [1108]	valid_0's binary_logloss: 0.256681
# [1109]	valid_0's binary_logloss: 0.256641
# [1110]	valid_0's binary_logloss: 0.256595
# [1111]	valid_0's binary_logloss: 0.256549
# [1112]	valid_0's binary_logloss: 0.256507
# [1113]	valid_0's binary_logloss: 0.256473
# [1114]	valid_0's binary_logloss: 0.256437
# [1115]	valid_0's binary_logloss: 0.256398
# [1116]	valid_0's binary_logloss: 0.256361
# [1117]	valid_0's binary_logloss: 0.256326
# [1118]	valid_0's binary_logloss: 0.256283
# [1119]	valid_0's binary_logloss: 0.256245
# [1120]	valid_0's binary_logloss: 0.256212
# [1121]	valid_0's binary_logloss: 0.256169
# [1122]	valid_0's binary_logloss: 0.256132
# [1123]	valid_0's binary_logloss: 0.256083
# [1124]	valid_0's binary_logloss: 0.256044
# [1125]	valid_0's binary_logloss: 0.256004
# [1126]	valid_0's binary_logloss: 0.255961
# [1127]	valid_0's binary_logloss: 0.255924
# [1128]	valid_0's binary_logloss: 0.255884
# [1129]	valid_0's binary_logloss: 0.255842
# [1130]	valid_0's binary_logloss: 0.255804
# [1131]	valid_0's binary_logloss: 0.255766
# [1132]	valid_0's binary_logloss: 0.255726
# [1133]	valid_0's binary_logloss: 0.255683
# [1134]	valid_0's binary_logloss: 0.255641
# [1135]	valid_0's binary_logloss: 0.255595
# [1136]	valid_0's binary_logloss: 0.255557
# [1137]	valid_0's binary_logloss: 0.25552
# [1138]	valid_0's binary_logloss: 0.255488
# [1139]	valid_0's binary_logloss: 0.255452
# [1140]	valid_0's binary_logloss: 0.255416
# [1141]	valid_0's binary_logloss: 0.255377
# [1142]	valid_0's binary_logloss: 0.255342
# [1143]	valid_0's binary_logloss: 0.255307
# [1144]	valid_0's binary_logloss: 0.255269
# [1145]	valid_0's binary_logloss: 0.255228
# [1146]	valid_0's binary_logloss: 0.255192
# [1147]	valid_0's binary_logloss: 0.255155
# [1148]	valid_0's binary_logloss: 0.255118
# [1149]	valid_0's binary_logloss: 0.255085
# [1150]	valid_0's binary_logloss: 0.255043
# [1151]	valid_0's binary_logloss: 0.255007
# [1152]	valid_0's binary_logloss: 0.254971
# [1153]	valid_0's binary_logloss: 0.25494
# [1154]	valid_0's binary_logloss: 0.254901
# [1155]	valid_0's binary_logloss: 0.254862
# [1156]	valid_0's binary_logloss: 0.254827
# [1157]	valid_0's binary_logloss: 0.254788
# [1158]	valid_0's binary_logloss: 0.254751
# [1159]	valid_0's binary_logloss: 0.254721
# [1160]	valid_0's binary_logloss: 0.254687
# [1161]	valid_0's binary_logloss: 0.254652
# [1162]	valid_0's binary_logloss: 0.254616
# [1163]	valid_0's binary_logloss: 0.254572
# [1164]	valid_0's binary_logloss: 0.254536
# [1165]	valid_0's binary_logloss: 0.254499
# [1166]	valid_0's binary_logloss: 0.254465
# [1167]	valid_0's binary_logloss: 0.25443
# [1168]	valid_0's binary_logloss: 0.254391
# [1169]	valid_0's binary_logloss: 0.254354
# [1170]	valid_0's binary_logloss: 0.254315
# [1171]	valid_0's binary_logloss: 0.25428
# ...
# [1230]	valid_0's binary_logloss: 0.252127
# [1231]	valid_0's binary_logloss: 0.252094
# [1232]	valid_0's binary_logloss: 0.252055
# [1233]	valid_0's binary_logloss: 0.252025
# [1234]	valid_0's binary_logloss: 0.251996
# [1235]	valid_0's binary_logloss: 0.25196
# [1236]	valid_0's binary_logloss: 0.251923
# [1237]	valid_0's binary_logloss: 0.251891
# [1238]	valid_0's binary_logloss: 0.251857
# [1239]	valid_0's binary_logloss: 0.251823
# [1240]	valid_0's binary_logloss: 0.25179
# [1241]	valid_0's binary_logloss: 0.25175
# [1242]	valid_0's binary_logloss: 0.251713
# [1243]	valid_0's binary_logloss: 0.25168
# [1244]	valid_0's binary_logloss: 0.251643
# [1245]	valid_0's binary_logloss: 0.251609
# [1246]	valid_0's binary_logloss: 0.251576
# [1247]	valid_0's binary_logloss: 0.251545
# [1248]	valid_0's binary_logloss: 0.251511
# [1249]	valid_0's binary_logloss: 0.251477
# [1250]	valid_0's binary_logloss: 0.251442
# [1251]	valid_0's binary_logloss: 0.251411
# [1252]	valid_0's binary_logloss: 0.251375
# [1253]	valid_0's binary_logloss: 0.251334
# [1254]	valid_0's binary_logloss: 0.25129
# [1255]	valid_0's binary_logloss: 0.251254
# [1256]	valid_0's binary_logloss: 0.251222
# [1257]	valid_0's binary_logloss: 0.251187
# [1258]	valid_0's binary_logloss: 0.251162
# [1259]	valid_0's binary_logloss: 0.251127
# [1260]	valid_0's binary_logloss: 0.251087
# [1261]	valid_0's binary_logloss: 0.251051
# [1262]	valid_0's binary_logloss: 0.251021
# [1263]	valid_0's binary_logloss: 0.250985
# [1264]	valid_0's binary_logloss: 0.25095
# [1265]	valid_0's binary_logloss: 0.250908
# [1266]	valid_0's binary_logloss: 0.250874
# [1267]	valid_0's binary_logloss: 0.250841
# [1268]	valid_0's binary_logloss: 0.250803
# [1269]	valid_0's binary_logloss: 0.25077
# [1270]	valid_0's binary_logloss: 0.250731
# [1271]	valid_0's binary_logloss: 0.2507
# [1272]	valid_0's binary_logloss: 0.250663
# [1273]	valid_0's binary_logloss: 0.250628
# [1274]	valid_0's binary_logloss: 0.25059
# [1275]	valid_0's binary_logloss: 0.250548
# [1276]	valid_0's binary_logloss: 0.250515
# [1277]	valid_0's binary_logloss: 0.250476
# [1278]	valid_0's binary_logloss: 0.250439
# [1279]	valid_0's binary_logloss: 0.250411
# [1280]	valid_0's binary_logloss: 0.250376
# [1281]	valid_0's binary_logloss: 0.250338
# [1282]	valid_0's binary_logloss: 0.250303
# [1283]	valid_0's binary_logloss: 0.250272
# [1284]	valid_0's binary_logloss: 0.25024
# [1285]	valid_0's binary_logloss: 0.250209
# [1286]	valid_0's binary_logloss: 0.250181
# [1287]	valid_0's binary_logloss: 0.250147
# [1288]	valid_0's binary_logloss: 0.25011
# [1289]	valid_0's binary_logloss: 0.250071
# [1290]	valid_0's binary_logloss: 0.250034
# [1291]	valid_0's binary_logloss: 0.25
# [1292]	valid_0's binary_logloss: 0.249968
# [1293]	valid_0's binary_logloss: 0.249934
# [1294]	valid_0's binary_logloss: 0.249898
# [1295]	valid_0's binary_logloss: 0.249862
# [1296]	valid_0's binary_logloss: 0.249831
# [1297]	valid_0's binary_logloss: 0.249796
# [1298]	valid_0's binary_logloss: 0.249769
# [1299]	valid_0's binary_logloss: 0.249739
# [1300]	valid_0's binary_logloss: 0.249708
# [1301]	valid_0's binary_logloss: 0.249674
# [1302]	valid_0's binary_logloss: 0.249645
# [1303]	valid_0's binary_logloss: 0.249613
# [1304]	valid_0's binary_logloss: 0.249573
# [1305]	valid_0's binary_logloss: 0.249537
# [1306]	valid_0's binary_logloss: 0.249499
# [1307]	valid_0's binary_logloss: 0.249464
# [1308]	valid_0's binary_logloss: 0.24943
# [1309]	valid_0's binary_logloss: 0.249394
# [1310]	valid_0's binary_logloss: 0.249361
# [1311]	valid_0's binary_logloss: 0.249331
# [1312]	valid_0's binary_logloss: 0.249298
# [1313]	valid_0's binary_logloss: 0.249262
# [1314]	valid_0's binary_logloss: 0.249235
# [1315]	valid_0's binary_logloss: 0.249191
# [1316]	valid_0's binary_logloss: 0.249159
# [1317]	valid_0's binary_logloss: 0.249131
# [1318]	valid_0's binary_logloss: 0.2491
# [1319]	valid_0's binary_logloss: 0.24907
# [1320]	valid_0's binary_logloss: 0.249042
# [1321]	valid_0's binary_logloss: 0.249009
# [1322]	valid_0's binary_logloss: 0.248979
# [1323]	valid_0's binary_logloss: 0.248946
# [1324]	valid_0's binary_logloss: 0.248912
# [1325]	valid_0's binary_logloss: 0.248877
# [1326]	valid_0's binary_logloss: 0.248843
# [1327]	valid_0's binary_logloss: 0.24881
# [1328]	valid_0's binary_logloss: 0.248771
# [1329]	valid_0's binary_logloss: 0.248737
# [1330]	valid_0's binary_logloss: 0.248706
# [1331]	valid_0's binary_logloss: 0.248676
# [1332]	valid_0's binary_logloss: 0.248653
# [1333]	valid_0's binary_logloss: 0.24862
# [1334]	valid_0's binary_logloss: 0.248582
# [1335]	valid_0's binary_logloss: 0.248554
# [1336]	valid_0's binary_logloss: 0.248523
# [1337]	valid_0's binary_logloss: 0.248496
# [1338]	valid_0's binary_logloss: 0.248465
# [1339]	valid_0's binary_logloss: 0.248431
# [1340]	valid_0's binary_logloss: 0.248396
# [1341]	valid_0's binary_logloss: 0.24837
# [1342]	valid_0's binary_logloss: 0.24834
# [1343]	valid_0's binary_logloss: 0.248311
# [1344]	valid_0's binary_logloss: 0.248276
# [1345]	valid_0's binary_logloss: 0.24825
# [1346]	valid_0's binary_logloss: 0.248215
# [1347]	valid_0's binary_logloss: 0.24818
# [1348]	valid_0's binary_logloss: 0.248152
# [1349]	valid_0's binary_logloss: 0.248119
# [1350]	valid_0's binary_logloss: 0.24809
# [1351]	valid_0's binary_logloss: 0.248063
# [1352]	valid_0's binary_logloss: 0.248035
# [1353]	valid_0's binary_logloss: 0.248003
# [1354]	valid_0's binary_logloss: 0.247974
# [1355]	valid_0's binary_logloss: 0.247941
# [1356]	valid_0's binary_logloss: 0.247914
# [1357]	valid_0's binary_logloss: 0.247885
# [1358]	valid_0's binary_logloss: 0.247853
# [1359]	valid_0's binary_logloss: 0.247822
# [1360]	valid_0's binary_logloss: 0.247796
# [1361]	valid_0's binary_logloss: 0.247762
# [1362]	valid_0's binary_logloss: 0.247729
# [1363]	valid_0's binary_logloss: 0.247703
# [1364]	valid_0's binary_logloss: 0.247669
# [1365]	valid_0's binary_logloss: 0.247637
# [1366]	valid_0's binary_logloss: 0.247612
# [1367]	valid_0's binary_logloss: 0.247582
# [1368]	valid_0's binary_logloss: 0.247551
# [1369]	valid_0's binary_logloss: 0.247516
# [1370]	valid_0's binary_logloss: 0.247492
# [1371]	valid_0's binary_logloss: 0.247457
# [1372]	valid_0's binary_logloss: 0.247428
# [1373]	valid_0's binary_logloss: 0.247399
# [1374]	valid_0's binary_logloss: 0.247369
# [1375]	valid_0's binary_logloss: 0.24734
# [1376]	valid_0's binary_logloss: 0.24731
# [1377]	valid_0's binary_logloss: 0.247275
# [1378]	valid_0's binary_logloss: 0.24724
# [1379]	valid_0's binary_logloss: 0.247208
# [1380]	valid_0's binary_logloss: 0.247177
# [1381]	valid_0's binary_logloss: 0.247145
# [1382]	valid_0's binary_logloss: 0.247106
# [1383]	valid_0's binary_logloss: 0.247071
# [1384]	valid_0's binary_logloss: 0.247041
# [1385]	valid_0's binary_logloss: 0.247006
# [1386]	valid_0's binary_logloss: 0.246976
# [1387]	valid_0's binary_logloss: 0.246949
# [1388]	valid_0's binary_logloss: 0.246916
# [1389]	valid_0's binary_logloss: 0.24688
# [1390]	valid_0's binary_logloss: 0.246848
# [1391]	valid_0's binary_logloss: 0.246816
# [1392]	valid_0's binary_logloss: 0.246782
# [1393]	valid_0's binary_logloss: 0.246754
# [1394]	valid_0's binary_logloss: 0.246728
# [1395]	valid_0's binary_logloss: 0.246698
# [1396]	valid_0's binary_logloss: 0.246668
# [1397]	valid_0's binary_logloss: 0.246639
# [1398]	valid_0's binary_logloss: 0.24661
# [1399]	valid_0's binary_logloss: 0.246575
# [1400]	valid_0's binary_logloss: 0.246544
# [1401]	valid_0's binary_logloss: 0.246502
# [1402]	valid_0's binary_logloss: 0.246474
# [1403]	valid_0's binary_logloss: 0.246444
# [1404]	valid_0's binary_logloss: 0.246415
# [1405]	valid_0's binary_logloss: 0.246385
# [1406]	valid_0's binary_logloss: 0.24636
# [1407]	valid_0's binary_logloss: 0.246324
# [1408]	valid_0's binary_logloss: 0.246293
# [1409]	valid_0's binary_logloss: 0.246265
# [1410]	valid_0's binary_logloss: 0.246242
# [1411]	valid_0's binary_logloss: 0.246213
# [1412]	valid_0's binary_logloss: 0.24618
# [1413]	valid_0's binary_logloss: 0.246152
# [1414]	valid_0's binary_logloss: 0.246123
# [1415]	valid_0's binary_logloss: 0.246092
# [1416]	valid_0's binary_logloss: 0.246066
# [1417]	valid_0's binary_logloss: 0.246039
# [1418]	valid_0's binary_logloss: 0.246013
# [1419]	valid_0's binary_logloss: 0.245986
# [1420]	valid_0's binary_logloss: 0.245957
# [1421]	valid_0's binary_logloss: 0.245927
# [1422]	valid_0's binary_logloss: 0.245893
# [1423]	valid_0's binary_logloss: 0.245851
# [1424]	valid_0's binary_logloss: 0.245825
# [1425]	valid_0's binary_logloss: 0.245796
# [1426]	valid_0's binary_logloss: 0.245767
# [1427]	valid_0's binary_logloss: 0.245739
# [1428]	valid_0's binary_logloss: 0.245706
# [1429]	valid_0's binary_logloss: 0.24568
# [1430]	valid_0's binary_logloss: 0.245651
# [1431]	valid_0's binary_logloss: 0.24562
# [1432]	valid_0's binary_logloss: 0.245592
# [1433]	valid_0's binary_logloss: 0.245564
# [1434]	valid_0's binary_logloss: 0.245537
# [1435]	valid_0's binary_logloss: 0.245501
# [1436]	valid_0's binary_logloss: 0.245469
# [1437]	valid_0's binary_logloss: 0.245437
# [1438]	valid_0's binary_logloss: 0.245393
# [1439]	valid_0's binary_logloss: 0.24537
# [1440]	valid_0's binary_logloss: 0.245345
# [1441]	valid_0's binary_logloss: 0.245314
# [1442]	valid_0's binary_logloss: 0.245283
# [1443]	valid_0's binary_logloss: 0.245258
# [1444]	valid_0's binary_logloss: 0.24523
# [1445]	valid_0's binary_logloss: 0.245205
# [1446]	valid_0's binary_logloss: 0.24517
# [1447]	valid_0's binary_logloss: 0.245144
# [1448]	valid_0's binary_logloss: 0.245113
# [1449]	valid_0's binary_logloss: 0.245088
# [1450]	valid_0's binary_logloss: 0.245061
# [1451]	valid_0's binary_logloss: 0.245031
# [1452]	valid_0's binary_logloss: 0.245001
# [1453]	valid_0's binary_logloss: 0.244974
# [1454]	valid_0's binary_logloss: 0.244947
# [1455]	valid_0's binary_logloss: 0.24492
# [1456]	valid_0's binary_logloss: 0.244885
# [1457]	valid_0's binary_logloss: 0.244854
# [1458]	valid_0's binary_logloss: 0.244822
# [1459]	valid_0's binary_logloss: 0.244799
# [1460]	valid_0's binary_logloss: 0.244769
# [1461]	valid_0's binary_logloss: 0.244737
# [1462]	valid_0's binary_logloss: 0.244706
# [1463]	valid_0's binary_logloss: 0.244683
# [1464]	valid_0's binary_logloss: 0.24465
# [1465]	valid_0's binary_logloss: 0.244622
# [1466]	valid_0's binary_logloss: 0.244594
# [1467]	valid_0's binary_logloss: 0.244567
# [1468]	valid_0's binary_logloss: 0.244537
# [1469]	valid_0's binary_logloss: 0.244506
# [1470]	valid_0's binary_logloss: 0.244479
# [1471]	valid_0's binary_logloss: 0.244449
# [1472]	valid_0's binary_logloss: 0.244421
# [1473]	valid_0's binary_logloss: 0.244389
# [1474]	valid_0's binary_logloss: 0.244364
# [1475]	valid_0's binary_logloss: 0.244327
# [1476]	valid_0's binary_logloss: 0.244292
# [1477]	valid_0's binary_logloss: 0.244265
# [1478]	valid_0's binary_logloss: 0.244236
# [1479]	valid_0's binary_logloss: 0.244204
# [1480]	valid_0's binary_logloss: 0.244175
# [1481]	valid_0's binary_logloss: 0.244148
# [1482]	valid_0's binary_logloss: 0.244116
# [1483]	valid_0's binary_logloss: 0.24409
# [1484]	valid_0's binary_logloss: 0.244064
# [1485]	valid_0's binary_logloss: 0.244035
# [1486]	valid_0's binary_logloss: 0.244013
# [1487]	valid_0's binary_logloss: 0.24399
# [1488]	valid_0's binary_logloss: 0.243961
# [1489]	valid_0's binary_logloss: 0.243938
# [1490]	valid_0's binary_logloss: 0.243911
# [1491]	valid_0's binary_logloss: 0.243885
# [1492]	valid_0's binary_logloss: 0.243859
# [1493]	valid_0's binary_logloss: 0.243836
# [1494]	valid_0's binary_logloss: 0.243807
# [1495]	valid_0's binary_logloss: 0.243775
# [1496]	valid_0's binary_logloss: 0.243746
# [1497]	valid_0's binary_logloss: 0.243715
# [1498]	valid_0's binary_logloss: 0.243691
# [1499]	valid_0's binary_logloss: 0.243662
# [1500]	valid_0's binary_logloss: 0.243635
# [1501]	valid_0's binary_logloss: 0.243601
# [1502]	valid_0's binary_logloss: 0.243576
# [1503]	valid_0's binary_logloss: 0.243544
# [1504]	valid_0's binary_logloss: 0.243513
# [1505]	valid_0's binary_logloss: 0.243488
# [1506]	valid_0's binary_logloss: 0.243461
# [1507]	valid_0's binary_logloss: 0.243428
# [1508]	valid_0's binary_logloss: 0.243398
# [1509]	valid_0's binary_logloss: 0.243369
# [1510]	valid_0's binary_logloss: 0.243343
# [1511]	valid_0's binary_logloss: 0.243309
# [1512]	valid_0's binary_logloss: 0.243284
# [1513]	valid_0's binary_logloss: 0.24326
# [1514]	valid_0's binary_logloss: 0.243225
# [1515]	valid_0's binary_logloss: 0.243192
# [1516]	valid_0's binary_logloss: 0.243154
# [1517]	valid_0's binary_logloss: 0.243128
# [1518]	valid_0's binary_logloss: 0.243098
# [1519]	valid_0's binary_logloss: 0.243075
# [1520]	valid_0's binary_logloss: 0.243055
# [1521]	valid_0's binary_logloss: 0.243031
# [1522]	valid_0's binary_logloss: 0.243009
# [1523]	valid_0's binary_logloss: 0.242984
# [1524]	valid_0's binary_logloss: 0.242957
# [1525]	valid_0's binary_logloss: 0.242923
# [1526]	valid_0's binary_logloss: 0.242895
# [1527]	valid_0's binary_logloss: 0.242871
# [1528]	valid_0's binary_logloss: 0.242845
# [1529]	valid_0's binary_logloss: 0.242812
# [1530]	valid_0's binary_logloss: 0.242778
# [1531]	valid_0's binary_logloss: 0.24274
# [1532]	valid_0's binary_logloss: 0.242711
# [1533]	valid_0's binary_logloss: 0.242682
# [1534]	valid_0's binary_logloss: 0.242652
# [1535]	valid_0's binary_logloss: 0.242624
# [1536]	valid_0's binary_logloss: 0.242598
# [1537]	valid_0's binary_logloss: 0.242573
# [1538]	valid_0's binary_logloss: 0.242543
# [1539]	valid_0's binary_logloss: 0.242516
# [1540]	valid_0's binary_logloss: 0.242485
# [1541]	valid_0's binary_logloss: 0.242461
# [1542]	valid_0's binary_logloss: 0.242429
# [1543]	valid_0's binary_logloss: 0.242406
# [1544]	valid_0's binary_logloss: 0.242385
# [1545]	valid_0's binary_logloss: 0.242358
# [1546]	valid_0's binary_logloss: 0.242332
# [1547]	valid_0's binary_logloss: 0.242313
# [1548]	valid_0's binary_logloss: 0.242284
# [1549]	valid_0's binary_logloss: 0.242253
# [1550]	valid_0's binary_logloss: 0.242229
# [1551]	valid_0's binary_logloss: 0.242203
# [1552]	valid_0's binary_logloss: 0.242173
# [1553]	valid_0's binary_logloss: 0.24215
# [1554]	valid_0's binary_logloss: 0.242123
# [1555]	valid_0's binary_logloss: 0.242094
# [1556]	valid_0's binary_logloss: 0.242064
# [1557]	valid_0's binary_logloss: 0.242035
# [1558]	valid_0's binary_logloss: 0.242014
# [1559]	valid_0's binary_logloss: 0.241986
# [1560]	valid_0's binary_logloss: 0.241962
# [1561]	valid_0's binary_logloss: 0.241935
# [1562]	valid_0's binary_logloss: 0.241908
# [1563]	valid_0's binary_logloss: 0.241884
# [1564]	valid_0's binary_logloss: 0.241851
# [1565]	valid_0's binary_logloss: 0.241829
# [1566]	valid_0's binary_logloss: 0.241805
# [1567]	valid_0's binary_logloss: 0.241779
# [1568]	valid_0's binary_logloss: 0.241748
# [1569]	valid_0's binary_logloss: 0.241725
# [1570]	valid_0's binary_logloss: 0.241697
# [1571]	valid_0's binary_logloss: 0.241667
# [1572]	valid_0's binary_logloss: 0.241639
# [1573]	valid_0's binary_logloss: 0.241603
# [1574]	valid_0's binary_logloss: 0.241578
# [1575]	valid_0's binary_logloss: 0.241556
# [1576]	valid_0's binary_logloss: 0.241526
# [1577]	valid_0's binary_logloss: 0.241497
# [1578]	valid_0's binary_logloss: 0.24147
# [1579]	valid_0's binary_logloss: 0.241445
# [1580]	valid_0's binary_logloss: 0.241413
# [1581]	valid_0's binary_logloss: 0.241386
# [1582]	valid_0's binary_logloss: 0.241365
# [1583]	valid_0's binary_logloss: 0.241341
# [1584]	valid_0's binary_logloss: 0.241315
# [1585]	valid_0's binary_logloss: 0.241288
# [1586]	valid_0's binary_logloss: 0.241262
# [1587]	valid_0's binary_logloss: 0.241236
# [1588]	valid_0's binary_logloss: 0.241209
# [1589]	valid_0's binary_logloss: 0.241181
# [1590]	valid_0's binary_logloss: 0.241159
# [1591]	valid_0's binary_logloss: 0.241131
# [1592]	valid_0's binary_logloss: 0.241105
# [1593]	valid_0's binary_logloss: 0.241075
# [1594]	valid_0's binary_logloss: 0.241044
# [1595]	valid_0's binary_logloss: 0.241022
# [1596]	valid_0's binary_logloss: 0.240998
# [1597]	valid_0's binary_logloss: 0.240973
# [1598]	valid_0's binary_logloss: 0.240941
# [1599]	valid_0's binary_logloss: 0.240905
# [1600]	valid_0's binary_logloss: 0.240876
#     ID_code    target
# 0    test_0  0.999215
# 1    test_1  0.998910
# 2    test_2  0.999096
# 3    test_3  0.107928
# 4    test_4  0.999032
# 5    test_5  0.998619
# 6    test_6  0.998854
# 7    test_7  0.107008
# 8    test_8  0.997786
# 9    test_9  0.998874
# 10  test_10  0.998795
# 11  test_11  0.050083
# 12  test_12  0.998628
# 13  test_13  0.998961
# 14  test_14  0.999169
# 15  test_15  0.103057
# 16  test_16  0.273821
# 17  test_17  0.085539
# 18  test_18  0.223688
# 19  test_19  0.999048

# %% [markdown]
# Neural Network from Scratch

# %%
from re import X
# Predicting with a neural net
df_train = pd.concat([pd.DataFrame(train),pd.DataFrame(target)], axis=1)
df_train.rename(columns={0:'target'},inplace=True)
splits = RandomSplitter()(range_of(df_train))
y_names = 'target'
cont_names = df_train.columns.tolist()[-len(df_train.columns.tolist())]
procs = [FillMissing, Normalize]
y_block = CategoryBlock()

# Building TabularPandas
to = TabularPandas(df_train.reset_index(), procs=procs, cont_names=cont_names, y_names=y_names, y_block=y_block, splits=splits)

## creating a dataloader
dls = to.dataloaders()

learn = tabular_learner(dls,[200,100],metrics=accuracy)

# Training the NN
learn.fit_one_cycle(10)
learn.lr_find()
result = learn.validate()
print(result)

# %%
# TODO: Make predictions for submit to Kaggle
df_test = pd.concat([pd.DataFrame(test),pd.DataFrame(synth)],axis=0)
dl = learn.dls.test_dl(df_test)
preds = learn.get_preds(dl=dl)
result = learn.validate()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
target = pd.DataFrame(preds[0][:,0].tolist())
ID_codes = pd.DataFrame(pd.read_csv("/content/drive/MyDrive/STAT4450_contest2_data/test.csv")['ID_code'])
submission0 = pd.concat([ID_codes,target],axis=1)
submission0.columns = list(["ID_code","target"])
submission0.to_csv("/content/drive/MyDrive/STAT4450_contest2_data/submission0.csv", index=False)
