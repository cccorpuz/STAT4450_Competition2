# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import lightgbm as lgb
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import accuracy_score, roc_curve, auc
import gc
import scipy.ndimage
from fastai.tabular.all import *
from google.colab import drive

# %% [markdown]
# Importing train.csv and test.csv

# %%
train = pd.read_csv("/content/drive/MyDrive/STAT4450_contest2_data/train.csv")
test = pd.read_csv("/content/drive/MyDrive/STAT4450_contest2_data/test.csv")

# %% [markdown]
# Removing fake results from test dataframe

# %%
test_codes = test["ID_code"].values
test.drop(["ID_code"], axis=1, inplace=True)
test = test.values

unique_count = np.zeros_like(test)  # same col & row size
for i in tqdm(range(test.shape[1])):
    _, index_, count_ = np.unique(test[:, i], return_counts=True, return_index=True)
    unique_count[index_[count_ == 1], i] += 1

real_idx = np.argwhere(np.sum(unique_count, axis=1) > 0)[:, 0]
synth_idx = np.argwhere(np.sum(unique_count, axis=1) == 0)[:, 0]

test_length = test.shape[0]
test_synth = test[synth_idx, :]
test = test[real_idx, :]

# 2. Append real test to training
target = np.array(list(train["target"].values))
train_length = train.shape[0]
train.drop(["ID_code"], axis=1, inplace=True)
train.drop(["target"], axis=1, inplace=True)
full = pd.DataFrame(np.concatenate([train.values, test]), columns=train.columns)
synth = pd.DataFrame(test_synth, columns=train.columns)
print(full.shape)

# Reverse features with negative correlation
features = [x for x in full.columns if x.startswith("var")]
for var in features:
    if np.corrcoef(target, train[var])[1][0] < 0:
        full[var] = full[var] * -1

# Getting Counts, Density, Deviation
sigma_fac = 0.001
sigma_base = 4
eps = 0.00000001
# Out:
# 100%|██████████| 200/200 [00:07<00:00, 26.94it/s]
# (300000, 200)

# %% [markdown]
# Defining a function to get feature counts

# %%
def get_features(data):
    # Get counts
    features_count = np.zeros((data.shape[0], len(features)))
    features_density = np.zeros((data.shape[0], len(features)))
    features_deviation = np.zeros((data.shape[0], len(features)))

    sigmas = []
    for i, var in enumerate(tqdm(features)):
        data_int = (data[var].values * 10000).round().astype(int)
        low = data_int.min()
        data_int -= low
        high = data_int.max() + 1
        counts_data = np.bincount(data_int, minlength=high).astype(float)

        # Geometric mean of twice sigma_base and a sigma_scaled which is scaled to the length of array
        sigma_scaled = counts_data.shape[0] * sigma_fac
        sigma = np.power(sigma_base * sigma_base * sigma_scaled, 1 / 3)
        sigmas.append(sigma)
        counts_data_smooth = scipy.ndimage.filters.gaussian_filter1d(counts_data, sigma)
        deviation = counts_data / (counts_data_smooth + eps)
        indices = data_int
        features_count[:, i] = counts_data[indices]
        features_density[:, i] = counts_data_smooth[indices]
        features_deviation[:, i] = deviation[indices]

    features_count_names = [var + "_count" for var in features]
    features_density_names = [var + "_density" for var in features]
    features_deviation_names = [var + "_deviation" for var in features]

    data_count = pd.DataFrame(columns=features_count_names, data=features_count)
    data_count.index = data.index
    data_density = pd.DataFrame(columns=features_density_names, data=features_density)
    data_density.index = data.index
    data_deviation = pd.DataFrame(
        columns=features_deviation_names, data=features_deviation
    )
    data_deviation.index = data.index
    data = pd.concat([data, data_count, data_density, data_deviation], axis=1)

    features_count = features_count_names
    features_density = features_density_names
    features_deviation = features_deviation_names

    return data, features_count, features_density, features_deviation

# %% [markdown]
# Getting the features and standardizing features

# %%
full, features_count, features_density, features_deviation = get_features(full)
(
    synth,
    fake_features_count,
    fake_features_density,
    fake_features_deviation,
) = get_features(synth)
print(full.shape)
print(f"test_synth: {synth.shape}")

# Standardizing the features
features_to_scale = [features, features_count]

scaler = StandardScaler()
features_to_scale_flatten = [var for sublist in features_to_scale for var in sublist]
scaler.fit(full[features_to_scale_flatten])
features_scaled = scaler.transform(full[features_to_scale_flatten])
full[features_to_scale_flatten] = features_scaled
print(full.shape)

# Split back into train and test
train = full.iloc[:train_length, :]
test = full.iloc[train_length:, :]
del full

gc.collect()
print(train.shape, test.shape)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]<ipython-input-8-e1a7dee16065>:19: DeprecationWarning: Please use `gaussian_filter1d` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   counts_data_smooth = scipy.ndimage.filters.gaussian_filter1d(counts_data, sigma)
# 100%|██████████| 200/200 [00:15<00:00, 13.06it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]<ipython-input-8-e1a7dee16065>:19: DeprecationWarning: Please use `gaussian_filter1d` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   counts_data_smooth = scipy.ndimage.filters.gaussian_filter1d(counts_data, sigma)
# 100%|██████████| 200/200 [00:10<00:00, 19.99it/s]
# (300000, 800)
# test_synth: (100000, 800)
# (300000, 800)
# (200000, 800) (100000, 800)

# %% [markdown]
# Light Gradient Boosting Machine (LGBM), 70-30 Split

# %%
x_train, x_val, y_train, y_val = train_test_split(
    train, target, test_size=0.3, random_state=123
)

train_data = lgb.Dataset(x_train, label=y_train)
val_data = lgb.Dataset(x_val, label=y_val)


# Param notes:
# 1. base
# 2. reg_lambda to 0.1 improve by 3%, num_leaves = 16
# 3. reg_lambda to 0.5
# 4. num_leaves to 64
# 5. num_leaves to 128, max_bin to 512
# 6. learning_rate to 0.05, num_rounds to 500
# 7. feature_fraction to 0.9
# 8*. Kazuki Onodera's submission params
# 9*. 8* combined with 7, leaving 1600 rounds
# 10*. 

# num_rounds = 500
# params = {
#     "boost_from_average": "false",
#     "boost": "gbdt",
#     "feature_fraction": 0.9,
#     "learning_rate": 0.05,
#     "max_depth": -1,
#     "metric": "binary_logloss",
#     "num_leaves": 64,
#     "num_threads": 4, #Only 4 Colab Pro cores
#     "tree_learner": "serial",
#     "objective": "binary",
#     "reg_alpha": 2, #Reduces features
#     "reg_lambda": 0.5, 
#     "verbosity": 1,
#     "max_bin": 512,
# }

# 8,9* model params below:
num_rounds = 1600
params = {
    'bagging_freq': 5,
    'bagging_fraction': 1.0,
    'boost_from_average':'false',
    'boost': 'gbdt',
    'feature_fraction': 0.9,
    'learning_rate': 0.05,
    'max_depth': -1,
    'metric':'binary_logloss',
    'min_data_in_leaf': 30,
    'min_sum_hessian_in_leaf': 10.0,
    'num_leaves': 64,
    'num_threads': 8,
    'tree_learner': 'serial',
    'objective': 'binary',
    'verbosity': 1,
    "max_bin": 512,
    }

# %%
# train the model
model = lgb.train(params, train_data, num_rounds, valid_sets=[val_data])

# make predictions on the validation data
# y_pred = model.predict(x_val)

# print the accuracy
# accuracy = accuracy_score(y_val, y_pred.round().astype(int))
# print(accuracy)

# Make final prediction for test
sub = pd.DataFrame({"ID_code": test_codes})

pred_real = model.predict(test)
pred_synth = model.predict(synth)

preds_all = np.zeros(test_length)
preds_all[real_idx] = pred_real
preds_all[synth_idx] = pred_synth
sub["target"] = preds_all
sub.to_csv("/content/drive/MyDrive/STAT4450_contest2_data/lgbsubmission10.csv", index=False)
print(sub.head(20))

# %% [markdown]
# LGBM, 5-Fold CV

# %%
# ============================================================================
# 5-Fold Cross Validation
# ============================================================================

kf = KFold(n_splits=5, shuffle=True, random_state=123)

accuracies = []
models = []
i = 0

av_preds_all = np.zeros(test_length)

# Loop through each fold
for train_index, val_index in kf.split(train):
    # Split the data into train and validation sets for this fold
    # label=pd.DataFrame(target).iloc[train_index],
    X_train = lgb.Dataset(train.iloc[train_index], label=target[train_index])
    X_val = lgb.Dataset(train.iloc[val_index], label=target[val_index])
    y_val = target[val_index]

    models.append(lgb.train(params, X_train, num_rounds, valid_sets=[X_val]))

    # Make predictions on the validation set for this fold
    y_pred = models[i].predict(train.iloc[val_index])

    # Make predictions on the test set for this fold
    # Instead of simply grabbing the highest scoring model, here we are trying to average all the models
    pred_real = models[i].predict(test)
    pred_synth = models[i].predict(synth)

    # Make predictions on the real and synthetic sets seperately then concatenate for final pred
    av_preds = np.zeros(test_length)
    av_preds[real_idx] = pred_real
    av_preds[synth_idx] = pred_synth

    av_preds_all += av_preds

    # Calculate the validation metric for this fold
    # Add the validation result to the list
    accuracy = accuracy_score(y_val, y_pred.round().astype(int))
    print(f"Accuracy on fold {i + 1}: {accuracy}")
    accuracies.append(accuracy)
    i += 1

# Calculate the average validation score across all folds
print(f"Mean accuracies: {np.mean(accuracies)}")
print(f"List of accuracies: {accuracies}")

# Select the best model to use in our final prediction
model = models[accuracies.index(max(accuracies))]

# Average the predictions made from av_preds_all
av_preds_all /= kf.get_n_splits()
# Out:
# Streaming output truncated to the last 5000 lines.
# [1422]	valid_0's binary_logloss: 0.205211
# [1423]	valid_0's binary_logloss: 0.205222
# [1424]	valid_0's binary_logloss: 0.205229
# [1425]	valid_0's binary_logloss: 0.205245
# [1426]	valid_0's binary_logloss: 0.205259
# [1427]	valid_0's binary_logloss: 0.20527
# [1428]	valid_0's binary_logloss: 0.205299
# [1429]	valid_0's binary_logloss: 0.2053
# [1430]	valid_0's binary_logloss: 0.205327
# [1431]	valid_0's binary_logloss: 0.205333
# [1432]	valid_0's binary_logloss: 0.205344
# [1433]	valid_0's binary_logloss: 0.205365
# [1434]	valid_0's binary_logloss: 0.205381
# [1435]	valid_0's binary_logloss: 0.205402
# [1436]	valid_0's binary_logloss: 0.205401
# [1437]	valid_0's binary_logloss: 0.205408
# [1438]	valid_0's binary_logloss: 0.205419
# [1439]	valid_0's binary_logloss: 0.205431
# [1440]	valid_0's binary_logloss: 0.205455
# [1441]	valid_0's binary_logloss: 0.205469
# [1442]	valid_0's binary_logloss: 0.205486
# [1443]	valid_0's binary_logloss: 0.205499
# [1444]	valid_0's binary_logloss: 0.205516
# [1445]	valid_0's binary_logloss: 0.205538
# [1446]	valid_0's binary_logloss: 0.205551
# [1447]	valid_0's binary_logloss: 0.205573
# [1448]	valid_0's binary_logloss: 0.20558
# [1512]	valid_0's binary_logloss: 0.206589
# [1513]	valid_0's binary_logloss: 0.206607
# [1514]	valid_0's binary_logloss: 0.206598
# [1515]	valid_0's binary_logloss: 0.206624
# [1516]	valid_0's binary_logloss: 0.206627
# [1517]	valid_0's binary_logloss: 0.206649
# [1518]	valid_0's binary_logloss: 0.20665
# [1519]	valid_0's binary_logloss: 0.206658
# [1520]	valid_0's binary_logloss: 0.206674
# [1521]	valid_0's binary_logloss: 0.206711
# [1522]	valid_0's binary_logloss: 0.206738
# [1523]	valid_0's binary_logloss: 0.206758
# [1524]	valid_0's binary_logloss: 0.206786
# [1525]	valid_0's binary_logloss: 0.206785
# [1526]	valid_0's binary_logloss: 0.206794
# [1527]	valid_0's binary_logloss: 0.206795
# [1528]	valid_0's binary_logloss: 0.206819
# [1529]	valid_0's binary_logloss: 0.206824
# [1530]	valid_0's binary_logloss: 0.206824
# [1531]	valid_0's binary_logloss: 0.206854
# [1532]	valid_0's binary_logloss: 0.206864
# [1533]	valid_0's binary_logloss: 0.206883
# [1534]	valid_0's binary_logloss: 0.206891
# [1535]	valid_0's binary_logloss: 0.206917
# [1536]	valid_0's binary_logloss: 0.206944
# [1537]	valid_0's binary_logloss: 0.206976
# [1538]	valid_0's binary_logloss: 0.206987
# [1539]	valid_0's binary_logloss: 0.206986
# [1540]	valid_0's binary_logloss: 0.206997
# [1541]	valid_0's binary_logloss: 0.207044
# [1542]	valid_0's binary_logloss: 0.207064
# [1543]	valid_0's binary_logloss: 0.207095
# [1544]	valid_0's binary_logloss: 0.207126
# [1545]	valid_0's binary_logloss: 0.207138
# [1546]	valid_0's binary_logloss: 0.207152
# [1547]	valid_0's binary_logloss: 0.207162
# [1548]	valid_0's binary_logloss: 0.207176
# [1549]	valid_0's binary_logloss: 0.207211
# [1550]	valid_0's binary_logloss: 0.207232
# [1551]	valid_0's binary_logloss: 0.207246
# [1552]	valid_0's binary_logloss: 0.207258
# [1553]	valid_0's binary_logloss: 0.207272
# [1554]	valid_0's binary_logloss: 0.207299
# [1555]	valid_0's binary_logloss: 0.207318
# [1556]	valid_0's binary_logloss: 0.207327
# [1557]	valid_0's binary_logloss: 0.207354
# [1558]	valid_0's binary_logloss: 0.207363
# [1559]	valid_0's binary_logloss: 0.20738
# [1560]	valid_0's binary_logloss: 0.207388
# [1561]	valid_0's binary_logloss: 0.207427
# [1562]	valid_0's binary_logloss: 0.207461
# [1563]	valid_0's binary_logloss: 0.207493
# [1564]	valid_0's binary_logloss: 0.207501
# [1565]	valid_0's binary_logloss: 0.207522
# [1566]	valid_0's binary_logloss: 0.207538
# [1567]	valid_0's binary_logloss: 0.207559
# [1568]	valid_0's binary_logloss: 0.207567
# [1569]	valid_0's binary_logloss: 0.207559
# [1570]	valid_0's binary_logloss: 0.207585
# [1571]	valid_0's binary_logloss: 0.2076
# [1572]	valid_0's binary_logloss: 0.207619
# [1573]	valid_0's binary_logloss: 0.207615
# [1574]	valid_0's binary_logloss: 0.207607
# [1575]	valid_0's binary_logloss: 0.207629
# [1576]	valid_0's binary_logloss: 0.20764
# [1577]	valid_0's binary_logloss: 0.207661
# [1578]	valid_0's binary_logloss: 0.207664
# [1579]	valid_0's binary_logloss: 0.207676
# [1580]	valid_0's binary_logloss: 0.207691
# [1581]	valid_0's binary_logloss: 0.207703
# [1582]	valid_0's binary_logloss: 0.207728
# [1583]	valid_0's binary_logloss: 0.207722
# [1584]	valid_0's binary_logloss: 0.207738
# [1585]	valid_0's binary_logloss: 0.207739
# [1586]	valid_0's binary_logloss: 0.207738
# [1587]	valid_0's binary_logloss: 0.207742
# [1588]	valid_0's binary_logloss: 0.207755
# [1589]	valid_0's binary_logloss: 0.207777
# [1590]	valid_0's binary_logloss: 0.20779
# [1591]	valid_0's binary_logloss: 0.20778
# [1592]	valid_0's binary_logloss: 0.207796
# [1593]	valid_0's binary_logloss: 0.207832
# [1594]	valid_0's binary_logloss: 0.207846
# [1595]	valid_0's binary_logloss: 0.20785
# [1596]	valid_0's binary_logloss: 0.207869
# [1597]	valid_0's binary_logloss: 0.207883
# [1598]	valid_0's binary_logloss: 0.207911
# [1599]	valid_0's binary_logloss: 0.20791
# [1600]	valid_0's binary_logloss: 0.207934
# Accuracy on fold 2: 0.92585
# [LightGBM] [Info] Number of positive: 16004, number of negative: 143996
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 2.481436 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 311155
# [LightGBM] [Info] Number of data points in the train set: 160000, number of used features: 800
# [1]	valid_0's binary_logloss: 0.66124
# [2]	valid_0's binary_logloss: 0.632435
# [3]	valid_0's binary_logloss: 0.606259
# [4]	valid_0's binary_logloss: 0.582383
# [5]	valid_0's binary_logloss: 0.560538
# [6]	valid_0's binary_logloss: 0.54062
# [7]	valid_0's binary_logloss: 0.522379
# [8]	valid_0's binary_logloss: 0.505568
# [9]	valid_0's binary_logloss: 0.490137
# [10]	valid_0's binary_logloss: 0.475872
# [11]	valid_0's binary_logloss: 0.462734
# [12]	valid_0's binary_logloss: 0.450657
# [13]	valid_0's binary_logloss: 0.439445
# [14]	valid_0's binary_logloss: 0.429127
# [15]	valid_0's binary_logloss: 0.419535
# [16]	valid_0's binary_logloss: 0.41066
# [17]	valid_0's binary_logloss: 0.402355
# [18]	valid_0's binary_logloss: 0.39472
# [19]	valid_0's binary_logloss: 0.387537
# [20]	valid_0's binary_logloss: 0.380862
# [21]	valid_0's binary_logloss: 0.374675
# [22]	valid_0's binary_logloss: 0.368992
# [23]	valid_0's binary_logloss: 0.363607
# [24]	valid_0's binary_logloss: 0.358622
# [25]	valid_0's binary_logloss: 0.353982
# [26]	valid_0's binary_logloss: 0.349616
# [27]	valid_0's binary_logloss: 0.345551
# [28]	valid_0's binary_logloss: 0.341712
# [29]	valid_0's binary_logloss: 0.338113
# [30]	valid_0's binary_logloss: 0.334729
# [31]	valid_0's binary_logloss: 0.331585
# [32]	valid_0's binary_logloss: 0.328707
# [33]	valid_0's binary_logloss: 0.3259
# [34]	valid_0's binary_logloss: 0.323349
# [35]	valid_0's binary_logloss: 0.320823
# [36]	valid_0's binary_logloss: 0.318542
# [37]	valid_0's binary_logloss: 0.316441
# [38]	valid_0's binary_logloss: 0.314319
# [39]	valid_0's binary_logloss: 0.312345
# [40]	valid_0's binary_logloss: 0.310458
# [41]	valid_0's binary_logloss: 0.308818
# [42]	valid_0's binary_logloss: 0.307234
# [43]	valid_0's binary_logloss: 0.305656
# [44]	valid_0's binary_logloss: 0.304137
# [45]	valid_0's binary_logloss: 0.302744
# [46]	valid_0's binary_logloss: 0.301398
# [47]	valid_0's binary_logloss: 0.299973
# [48]	valid_0's binary_logloss: 0.298747
# [49]	valid_0's binary_logloss: 0.29754
# [50]	valid_0's binary_logloss: 0.296354
# [51]	valid_0's binary_logloss: 0.295236
# [52]	valid_0's binary_logloss: 0.294132
# [53]	valid_0's binary_logloss: 0.293109
# [54]	valid_0's binary_logloss: 0.292101
# [55]	valid_0's binary_logloss: 0.291177
# [56]	valid_0's binary_logloss: 0.29038
# [57]	valid_0's binary_logloss: 0.289513
# [58]	valid_0's binary_logloss: 0.288562
# [59]	valid_0's binary_logloss: 0.28776
# [60]	valid_0's binary_logloss: 0.286902
# [61]	valid_0's binary_logloss: 0.285986
# [62]	valid_0's binary_logloss: 0.285253
# [63]	valid_0's binary_logloss: 0.284544
# [64]	valid_0's binary_logloss: 0.283771
# [65]	valid_0's binary_logloss: 0.28315
# [66]	valid_0's binary_logloss: 0.282427
# [67]	valid_0's binary_logloss: 0.281687
# [68]	valid_0's binary_logloss: 0.280936
# [69]	valid_0's binary_logloss: 0.28022
# [70]	valid_0's binary_logloss: 0.279528
# [71]	valid_0's binary_logloss: 0.278857
# [72]	valid_0's binary_logloss: 0.278197
# [73]	valid_0's binary_logloss: 0.277616
# [74]	valid_0's binary_logloss: 0.277024
# [75]	valid_0's binary_logloss: 0.276382
# [76]	valid_0's binary_logloss: 0.275791
# [77]	valid_0's binary_logloss: 0.275219
# [78]	valid_0's binary_logloss: 0.274715
# [79]	valid_0's binary_logloss: 0.27408
# [80]	valid_0's binary_logloss: 0.273452
# [81]	valid_0's binary_logloss: 0.272909
# [82]	valid_0's binary_logloss: 0.272335
# [83]	valid_0's binary_logloss: 0.271792
# [84]	valid_0's binary_logloss: 0.271219
# [85]	valid_0's binary_logloss: 0.270734
# [86]	valid_0's binary_logloss: 0.270169
# [87]	valid_0's binary_logloss: 0.269556
# [88]	valid_0's binary_logloss: 0.269071
# [89]	valid_0's binary_logloss: 0.268584
# [90]	valid_0's binary_logloss: 0.268059
# [91]	valid_0's binary_logloss: 0.267541
# [92]	valid_0's binary_logloss: 0.267066
# [93]	valid_0's binary_logloss: 0.266595
# [94]	valid_0's binary_logloss: 0.266128
# [95]	valid_0's binary_logloss: 0.265659
# [96]	valid_0's binary_logloss: 0.265184
# [97]	valid_0's binary_logloss: 0.264748
# [98]	valid_0's binary_logloss: 0.264306
# [99]	valid_0's binary_logloss: 0.26387
# [100]	valid_0's binary_logloss: 0.263375
# [101]	valid_0's binary_logloss: 0.262947
# [102]	valid_0's binary_logloss: 0.262593
# [103]	valid_0's binary_logloss: 0.262219
# [104]	valid_0's binary_logloss: 0.261814
# [105]	valid_0's binary_logloss: 0.261369
# [106]	valid_0's binary_logloss: 0.260971
# [107]	valid_0's binary_logloss: 0.260562
# [108]	valid_0's binary_logloss: 0.260169
# [109]	valid_0's binary_logloss: 0.259759
# [110]	valid_0's binary_logloss: 0.259353
# [111]	valid_0's binary_logloss: 0.258996
# [112]	valid_0's binary_logloss: 0.25864
# [113]	valid_0's binary_logloss: 0.258321
# [114]	valid_0's binary_logloss: 0.257925
# [115]	valid_0's binary_logloss: 0.257454
# [116]	valid_0's binary_logloss: 0.257095
# [117]	valid_0's binary_logloss: 0.256675
# [118]	valid_0's binary_logloss: 0.256318
# [119]	valid_0's binary_logloss: 0.25598
# [120]	valid_0's binary_logloss: 0.255651
# [121]	valid_0's binary_logloss: 0.255382
# [122]	valid_0's binary_logloss: 0.255054
# [123]	valid_0's binary_logloss: 0.254688
# [124]	valid_0's binary_logloss: 0.254349
# [125]	valid_0's binary_logloss: 0.253984
# [126]	valid_0's binary_logloss: 0.253608
# [127]	valid_0's binary_logloss: 0.253297
# [128]	valid_0's binary_logloss: 0.252934
# [129]	valid_0's binary_logloss: 0.252602
# [130]	valid_0's binary_logloss: 0.252295
# [131]	valid_0's binary_logloss: 0.251942
# [132]	valid_0's binary_logloss: 0.251581
# [133]	valid_0's binary_logloss: 0.251354
# [134]	valid_0's binary_logloss: 0.251117
# [135]	valid_0's binary_logloss: 0.250832
# [136]	valid_0's binary_logloss: 0.250532
# [137]	valid_0's binary_logloss: 0.250181
# [138]	valid_0's binary_logloss: 0.249978
# [139]	valid_0's binary_logloss: 0.249673
# [140]	valid_0's binary_logloss: 0.249325
# [141]	valid_0's binary_logloss: 0.249055
# [142]	valid_0's binary_logloss: 0.248793
# [143]	valid_0's binary_logloss: 0.248521
# [144]	valid_0's binary_logloss: 0.248258
# [145]	valid_0's binary_logloss: 0.247965
# [146]	valid_0's binary_logloss: 0.247677
# [147]	valid_0's binary_logloss: 0.247365
# [148]	valid_0's binary_logloss: 0.247074
# [149]	valid_0's binary_logloss: 0.246763
# [150]	valid_0's binary_logloss: 0.246538
# [151]	valid_0's binary_logloss: 0.24623
# [152]	valid_0's binary_logloss: 0.245942
# [153]	valid_0's binary_logloss: 0.245694
# [154]	valid_0's binary_logloss: 0.245465
# [155]	valid_0's binary_logloss: 0.245225
# [156]	valid_0's binary_logloss: 0.244958
# [157]	valid_0's binary_logloss: 0.244758
# [158]	valid_0's binary_logloss: 0.244494
# [159]	valid_0's binary_logloss: 0.244239
# [160]	valid_0's binary_logloss: 0.24401
# [161]	valid_0's binary_logloss: 0.243741
# [162]	valid_0's binary_logloss: 0.243541
# [163]	valid_0's binary_logloss: 0.243287
# [164]	valid_0's binary_logloss: 0.242987
# [165]	valid_0's binary_logloss: 0.242747
# [166]	valid_0's binary_logloss: 0.242473
# [167]	valid_0's binary_logloss: 0.242211
# [168]	valid_0's binary_logloss: 0.241949
# [235]	valid_0's binary_logloss: 0.229907
# [236]	valid_0's binary_logloss: 0.229785
# [237]	valid_0's binary_logloss: 0.229658
# [238]	valid_0's binary_logloss: 0.229517
# [239]	valid_0's binary_logloss: 0.229388
# [240]	valid_0's binary_logloss: 0.229286
# [241]	valid_0's binary_logloss: 0.22919
# [242]	valid_0's binary_logloss: 0.229082
# [243]	valid_0's binary_logloss: 0.22891
# [244]	valid_0's binary_logloss: 0.228793
# [245]	valid_0's binary_logloss: 0.228661
# [246]	valid_0's binary_logloss: 0.228509
# [247]	valid_0's binary_logloss: 0.228371
# [248]	valid_0's binary_logloss: 0.228255
# [249]	valid_0's binary_logloss: 0.228113
# [250]	valid_0's binary_logloss: 0.227995
# [251]	valid_0's binary_logloss: 0.227861
# [252]	valid_0's binary_logloss: 0.227742
# [253]	valid_0's binary_logloss: 0.227637
# [254]	valid_0's binary_logloss: 0.227496
# [255]	valid_0's binary_logloss: 0.227357
# [256]	valid_0's binary_logloss: 0.227257
# [257]	valid_0's binary_logloss: 0.227175
# [258]	valid_0's binary_logloss: 0.227066
# [259]	valid_0's binary_logloss: 0.226944
# [260]	valid_0's binary_logloss: 0.226868
# [261]	valid_0's binary_logloss: 0.226751
# [262]	valid_0's binary_logloss: 0.226661
# [263]	valid_0's binary_logloss: 0.226534
# [264]	valid_0's binary_logloss: 0.226401
# [265]	valid_0's binary_logloss: 0.226302
# [266]	valid_0's binary_logloss: 0.226195
# [267]	valid_0's binary_logloss: 0.226071
# [268]	valid_0's binary_logloss: 0.225972
# [269]	valid_0's binary_logloss: 0.225847
# [270]	valid_0's binary_logloss: 0.225769
# [271]	valid_0's binary_logloss: 0.225636
# [272]	valid_0's binary_logloss: 0.225568
# [273]	valid_0's binary_logloss: 0.225473
# [274]	valid_0's binary_logloss: 0.225364
# [275]	valid_0's binary_logloss: 0.225243
# [276]	valid_0's binary_logloss: 0.225178
# [277]	valid_0's binary_logloss: 0.225052
# [278]	valid_0's binary_logloss: 0.224931
# [279]	valid_0's binary_logloss: 0.224767
# [280]	valid_0's binary_logloss: 0.224668
# [281]	valid_0's binary_logloss: 0.224602
# [282]	valid_0's binary_logloss: 0.224518
# [283]	valid_0's binary_logloss: 0.224456
# [284]	valid_0's binary_logloss: 0.224378
# [285]	valid_0's binary_logloss: 0.224288
# [286]	valid_0's binary_logloss: 0.224191
# [287]	valid_0's binary_logloss: 0.224095
# [288]	valid_0's binary_logloss: 0.224
# [289]	valid_0's binary_logloss: 0.2239
# [290]	valid_0's binary_logloss: 0.223803
# [291]	valid_0's binary_logloss: 0.223713
# [292]	valid_0's binary_logloss: 0.223612
# [293]	valid_0's binary_logloss: 0.223515
# [294]	valid_0's binary_logloss: 0.223412
# [295]	valid_0's binary_logloss: 0.223377
# [296]	valid_0's binary_logloss: 0.223235
# [297]	valid_0's binary_logloss: 0.223117
# [298]	valid_0's binary_logloss: 0.222999
# [299]	valid_0's binary_logloss: 0.22293
# [300]	valid_0's binary_logloss: 0.222872
# [301]	valid_0's binary_logloss: 0.222788
# [302]	valid_0's binary_logloss: 0.222671
# [303]	valid_0's binary_logloss: 0.222575
# [304]	valid_0's binary_logloss: 0.222496
# [305]	valid_0's binary_logloss: 0.222408
# [306]	valid_0's binary_logloss: 0.222319
# [307]	valid_0's binary_logloss: 0.22221
# [308]	valid_0's binary_logloss: 0.222154
# [309]	valid_0's binary_logloss: 0.222013
# [310]	valid_0's binary_logloss: 0.221935
# [311]	valid_0's binary_logloss: 0.221831
# [312]	valid_0's binary_logloss: 0.221724
# [313]	valid_0's binary_logloss: 0.221632
# [314]	valid_0's binary_logloss: 0.221554
# [315]	valid_0's binary_logloss: 0.221494
# [316]	valid_0's binary_logloss: 0.2214
# [317]	valid_0's binary_logloss: 0.221339
# [318]	valid_0's binary_logloss: 0.221232
# [319]	valid_0's binary_logloss: 0.221139
# [320]	valid_0's binary_logloss: 0.221063
# [321]	valid_0's binary_logloss: 0.220982
# [322]	valid_0's binary_logloss: 0.220896
# [323]	valid_0's binary_logloss: 0.220821
# [324]	valid_0's binary_logloss: 0.220723
# [325]	valid_0's binary_logloss: 0.220641
# [326]	valid_0's binary_logloss: 0.220542
# [327]	valid_0's binary_logloss: 0.220491
# [328]	valid_0's binary_logloss: 0.220402
# [329]	valid_0's binary_logloss: 0.220309
# [330]	valid_0's binary_logloss: 0.220186
# [331]	valid_0's binary_logloss: 0.220113
# [332]	valid_0's binary_logloss: 0.220049
# [333]	valid_0's binary_logloss: 0.21999
# [334]	valid_0's binary_logloss: 0.219896
# [335]	valid_0's binary_logloss: 0.219806
# [336]	valid_0's binary_logloss: 0.219703
# [337]	valid_0's binary_logloss: 0.219648
# [338]	valid_0's binary_logloss: 0.219566
# [339]	valid_0's binary_logloss: 0.219509
# [340]	valid_0's binary_logloss: 0.219467
# [341]	valid_0's binary_logloss: 0.219385
# [342]	valid_0's binary_logloss: 0.219293
# [343]	valid_0's binary_logloss: 0.219214
# [344]	valid_0's binary_logloss: 0.219143
# [345]	valid_0's binary_logloss: 0.219087
# [346]	valid_0's binary_logloss: 0.219036
# [347]	valid_0's binary_logloss: 0.218929
# [348]	valid_0's binary_logloss: 0.218871
# [349]	valid_0's binary_logloss: 0.218769
# [350]	valid_0's binary_logloss: 0.218686
# [351]	valid_0's binary_logloss: 0.218655
# [352]	valid_0's binary_logloss: 0.218568
# [353]	valid_0's binary_logloss: 0.218444
# [354]	valid_0's binary_logloss: 0.218403
# [355]	valid_0's binary_logloss: 0.218353
# [356]	valid_0's binary_logloss: 0.218287
# [357]	valid_0's binary_logloss: 0.218208
# [358]	valid_0's binary_logloss: 0.218129
# [359]	valid_0's binary_logloss: 0.218052
# [360]	valid_0's binary_logloss: 0.217989
# [361]	valid_0's binary_logloss: 0.217913
# [362]	valid_0's binary_logloss: 0.217859
# [363]	valid_0's binary_logloss: 0.217794
# [364]	valid_0's binary_logloss: 0.21769
# [365]	valid_0's binary_logloss: 0.217607
# [366]	valid_0's binary_logloss: 0.217527
# [433]	valid_0's binary_logloss: 0.214137
# [434]	valid_0's binary_logloss: 0.214075
# [435]	valid_0's binary_logloss: 0.214016
# [436]	valid_0's binary_logloss: 0.213932
# [437]	valid_0's binary_logloss: 0.213895
# [438]	valid_0's binary_logloss: 0.213862
# [439]	valid_0's binary_logloss: 0.213801
# [440]	valid_0's binary_logloss: 0.213767
# [441]	valid_0's binary_logloss: 0.213728
# [442]	valid_0's binary_logloss: 0.213687
# [443]	valid_0's binary_logloss: 0.213652
# [444]	valid_0's binary_logloss: 0.213623
# [445]	valid_0's binary_logloss: 0.213592
# [446]	valid_0's binary_logloss: 0.213563
# [447]	valid_0's binary_logloss: 0.213514
# [448]	valid_0's binary_logloss: 0.213442
# [449]	valid_0's binary_logloss: 0.213418
# [450]	valid_0's binary_logloss: 0.213387
# [451]	valid_0's binary_logloss: 0.213366
# [452]	valid_0's binary_logloss: 0.213353
# [453]	valid_0's binary_logloss: 0.213316
# [454]	valid_0's binary_logloss: 0.213275
# [455]	valid_0's binary_logloss: 0.213227
# [456]	valid_0's binary_logloss: 0.213182
# [457]	valid_0's binary_logloss: 0.21315
# [458]	valid_0's binary_logloss: 0.213158
# [459]	valid_0's binary_logloss: 0.213134
# [460]	valid_0's binary_logloss: 0.213111
# [461]	valid_0's binary_logloss: 0.213079
# [462]	valid_0's binary_logloss: 0.213026
# [463]	valid_0's binary_logloss: 0.213003
# [464]	valid_0's binary_logloss: 0.212982
# [465]	valid_0's binary_logloss: 0.212949
# [466]	valid_0's binary_logloss: 0.212893
# [467]	valid_0's binary_logloss: 0.212861
# [468]	valid_0's binary_logloss: 0.212776
# [469]	valid_0's binary_logloss: 0.212743
# [470]	valid_0's binary_logloss: 0.212731
# [471]	valid_0's binary_logloss: 0.21272
# [472]	valid_0's binary_logloss: 0.212696
# [473]	valid_0's binary_logloss: 0.212685
# [474]	valid_0's binary_logloss: 0.212681
# [475]	valid_0's binary_logloss: 0.212629
# [476]	valid_0's binary_logloss: 0.212615
# [477]	valid_0's binary_logloss: 0.212553
# [478]	valid_0's binary_logloss: 0.212517
# [479]	valid_0's binary_logloss: 0.212446
# [480]	valid_0's binary_logloss: 0.212411
# [481]	valid_0's binary_logloss: 0.212367
# [482]	valid_0's binary_logloss: 0.21233
# [483]	valid_0's binary_logloss: 0.21229
# [484]	valid_0's binary_logloss: 0.212273
# [485]	valid_0's binary_logloss: 0.21225
# [486]	valid_0's binary_logloss: 0.212227
# [487]	valid_0's binary_logloss: 0.212168
# [488]	valid_0's binary_logloss: 0.212159
# [489]	valid_0's binary_logloss: 0.212095
# [490]	valid_0's binary_logloss: 0.212067
# [491]	valid_0's binary_logloss: 0.212016
# [492]	valid_0's binary_logloss: 0.211985
# [493]	valid_0's binary_logloss: 0.211959
# [494]	valid_0's binary_logloss: 0.211908
# [495]	valid_0's binary_logloss: 0.211901
# [496]	valid_0's binary_logloss: 0.21187
# [497]	valid_0's binary_logloss: 0.211836
# [498]	valid_0's binary_logloss: 0.211783
# [565]	valid_0's binary_logloss: 0.210031
# [566]	valid_0's binary_logloss: 0.210015
# [567]	valid_0's binary_logloss: 0.209978
# [568]	valid_0's binary_logloss: 0.209964
# [569]	valid_0's binary_logloss: 0.209951
# [570]	valid_0's binary_logloss: 0.209925
# [571]	valid_0's binary_logloss: 0.209883
# [572]	valid_0's binary_logloss: 0.20984
# [573]	valid_0's binary_logloss: 0.209829
# [574]	valid_0's binary_logloss: 0.209803
# [575]	valid_0's binary_logloss: 0.209791
# [576]	valid_0's binary_logloss: 0.209766
# [577]	valid_0's binary_logloss: 0.209749
# [578]	valid_0's binary_logloss: 0.209747
# [579]	valid_0's binary_logloss: 0.209739
# [580]	valid_0's binary_logloss: 0.209724
# [581]	valid_0's binary_logloss: 0.209678
# [582]	valid_0's binary_logloss: 0.209639
# [583]	valid_0's binary_logloss: 0.209632
# [584]	valid_0's binary_logloss: 0.209628
# [585]	valid_0's binary_logloss: 0.209628
# [586]	valid_0's binary_logloss: 0.209627
# [587]	valid_0's binary_logloss: 0.209616
# [588]	valid_0's binary_logloss: 0.209583
# [589]	valid_0's binary_logloss: 0.209562
# [590]	valid_0's binary_logloss: 0.209553
# [591]	valid_0's binary_logloss: 0.209546
# [592]	valid_0's binary_logloss: 0.209566
# [593]	valid_0's binary_logloss: 0.20953
# [594]	valid_0's binary_logloss: 0.20948
# [595]	valid_0's binary_logloss: 0.20947
# [596]	valid_0's binary_logloss: 0.209444
# [597]	valid_0's binary_logloss: 0.209431
# [598]	valid_0's binary_logloss: 0.209402
# [599]	valid_0's binary_logloss: 0.209383
# [600]	valid_0's binary_logloss: 0.209404
# [601]	valid_0's binary_logloss: 0.209405
# [602]	valid_0's binary_logloss: 0.209407
# [603]	valid_0's binary_logloss: 0.209406
# [604]	valid_0's binary_logloss: 0.209419
# [605]	valid_0's binary_logloss: 0.209436
# [606]	valid_0's binary_logloss: 0.209448
# [607]	valid_0's binary_logloss: 0.209444
# [608]	valid_0's binary_logloss: 0.209409
# [609]	valid_0's binary_logloss: 0.209388
# [610]	valid_0's binary_logloss: 0.209364
# [611]	valid_0's binary_logloss: 0.20934
# [612]	valid_0's binary_logloss: 0.209339
# [613]	valid_0's binary_logloss: 0.209341
# [614]	valid_0's binary_logloss: 0.209325
# [615]	valid_0's binary_logloss: 0.209309
# [616]	valid_0's binary_logloss: 0.209309
# [617]	valid_0's binary_logloss: 0.209274
# [618]	valid_0's binary_logloss: 0.209261
# [619]	valid_0's binary_logloss: 0.209245
# [620]	valid_0's binary_logloss: 0.209245
# [621]	valid_0's binary_logloss: 0.209261
# [622]	valid_0's binary_logloss: 0.209237
# [623]	valid_0's binary_logloss: 0.209253
# [624]	valid_0's binary_logloss: 0.209236
# [625]	valid_0's binary_logloss: 0.209242
# [626]	valid_0's binary_logloss: 0.209225
# [627]	valid_0's binary_logloss: 0.209216
# [628]	valid_0's binary_logloss: 0.209212
# [629]	valid_0's binary_logloss: 0.209207
# [630]	valid_0's binary_logloss: 0.20917
# [631]	valid_0's binary_logloss: 0.209169
# [632]	valid_0's binary_logloss: 0.209157
# [633]	valid_0's binary_logloss: 0.209172
# [634]	valid_0's binary_logloss: 0.209171
# [635]	valid_0's binary_logloss: 0.209161
# [636]	valid_0's binary_logloss: 0.209169
# [637]	valid_0's binary_logloss: 0.209182
# [638]	valid_0's binary_logloss: 0.209185
# [639]	valid_0's binary_logloss: 0.209175
# [640]	valid_0's binary_logloss: 0.209165
# [641]	valid_0's binary_logloss: 0.20914
# [642]	valid_0's binary_logloss: 0.209138
# [643]	valid_0's binary_logloss: 0.209126
# [644]	valid_0's binary_logloss: 0.209127
# [645]	valid_0's binary_logloss: 0.209097
# [646]	valid_0's binary_logloss: 0.209113
# [647]	valid_0's binary_logloss: 0.209132
# [648]	valid_0's binary_logloss: 0.209125
# [649]	valid_0's binary_logloss: 0.209144
# [650]	valid_0's binary_logloss: 0.209132
# [651]	valid_0's binary_logloss: 0.20913
# [652]	valid_0's binary_logloss: 0.209114
# [653]	valid_0's binary_logloss: 0.209125
# [654]	valid_0's binary_logloss: 0.209142
# [655]	valid_0's binary_logloss: 0.20914
# [656]	valid_0's binary_logloss: 0.209132
# [657]	valid_0's binary_logloss: 0.209094
# [658]	valid_0's binary_logloss: 0.209092
# [659]	valid_0's binary_logloss: 0.209103
# [660]	valid_0's binary_logloss: 0.209093
# [661]	valid_0's binary_logloss: 0.209088
# [662]	valid_0's binary_logloss: 0.209072
# [663]	valid_0's binary_logloss: 0.209073
# [664]	valid_0's binary_logloss: 0.209075
# [665]	valid_0's binary_logloss: 0.209067
# [666]	valid_0's binary_logloss: 0.209082
# [667]	valid_0's binary_logloss: 0.209079
# [668]	valid_0's binary_logloss: 0.209083
# [669]	valid_0's binary_logloss: 0.209081
# [670]	valid_0's binary_logloss: 0.209055
# [671]	valid_0's binary_logloss: 0.209045
# [672]	valid_0's binary_logloss: 0.209017
# [673]	valid_0's binary_logloss: 0.208977
# [674]	valid_0's binary_logloss: 0.208967
# [675]	valid_0's binary_logloss: 0.208957
# [676]	valid_0's binary_logloss: 0.208973
# [677]	valid_0's binary_logloss: 0.208981
# [678]	valid_0's binary_logloss: 0.208987
# [679]	valid_0's binary_logloss: 0.20898
# [680]	valid_0's binary_logloss: 0.208962
# [681]	valid_0's binary_logloss: 0.208941
# [682]	valid_0's binary_logloss: 0.208949
# [683]	valid_0's binary_logloss: 0.208958
# [684]	valid_0's binary_logloss: 0.208956
# [685]	valid_0's binary_logloss: 0.208949
# [686]	valid_0's binary_logloss: 0.208947
# [687]	valid_0's binary_logloss: 0.208948
# [688]	valid_0's binary_logloss: 0.208958
# [689]	valid_0's binary_logloss: 0.208965
# [690]	valid_0's binary_logloss: 0.208957
# [691]	valid_0's binary_logloss: 0.208966
# [692]	valid_0's binary_logloss: 0.208949
# [693]	valid_0's binary_logloss: 0.208948
# [694]	valid_0's binary_logloss: 0.208948
# [695]	valid_0's binary_logloss: 0.208931
# [696]	valid_0's binary_logloss: 0.20892
# [697]	valid_0's binary_logloss: 0.208917
# [698]	valid_0's binary_logloss: 0.208939
# [699]	valid_0's binary_logloss: 0.208916
# [700]	valid_0's binary_logloss: 0.208914
# [701]	valid_0's binary_logloss: 0.208925
# [702]	valid_0's binary_logloss: 0.208915
# [703]	valid_0's binary_logloss: 0.208909
# [704]	valid_0's binary_logloss: 0.208921
# [705]	valid_0's binary_logloss: 0.208927
# [706]	valid_0's binary_logloss: 0.20892
# [707]	valid_0's binary_logloss: 0.208923
# [708]	valid_0's binary_logloss: 0.208904
# [709]	valid_0's binary_logloss: 0.208939
# [710]	valid_0's binary_logloss: 0.208934
# [711]	valid_0's binary_logloss: 0.20894
# [712]	valid_0's binary_logloss: 0.208944
# [713]	valid_0's binary_logloss: 0.208964
# [714]	valid_0's binary_logloss: 0.208949
# [715]	valid_0's binary_logloss: 0.208934
# [716]	valid_0's binary_logloss: 0.208944
# [717]	valid_0's binary_logloss: 0.20894
# [718]	valid_0's binary_logloss: 0.208963
# [719]	valid_0's binary_logloss: 0.208959
# [720]	valid_0's binary_logloss: 0.208959
# [721]	valid_0's binary_logloss: 0.208938
# [722]	valid_0's binary_logloss: 0.208919
# [723]	valid_0's binary_logloss: 0.2089
# [724]	valid_0's binary_logloss: 0.20891
# [725]	valid_0's binary_logloss: 0.2089
# [726]	valid_0's binary_logloss: 0.208912
# [727]	valid_0's binary_logloss: 0.20891
# [728]	valid_0's binary_logloss: 0.208872
# [729]	valid_0's binary_logloss: 0.208862
# [730]	valid_0's binary_logloss: 0.208873
# [731]	valid_0's binary_logloss: 0.208876
# [732]	valid_0's binary_logloss: 0.208869
# [733]	valid_0's binary_logloss: 0.208878
# [734]	valid_0's binary_logloss: 0.20886
# [735]	valid_0's binary_logloss: 0.208874
# [736]	valid_0's binary_logloss: 0.208877
# [737]	valid_0's binary_logloss: 0.208835
# [738]	valid_0's binary_logloss: 0.208811
# [739]	valid_0's binary_logloss: 0.208814
# [740]	valid_0's binary_logloss: 0.208811
# [741]	valid_0's binary_logloss: 0.208812
# [742]	valid_0's binary_logloss: 0.208799
# [743]	valid_0's binary_logloss: 0.208772
# [744]	valid_0's binary_logloss: 0.208745
# [745]	valid_0's binary_logloss: 0.208758
# [746]	valid_0's binary_logloss: 0.208757
# [747]	valid_0's binary_logloss: 0.208775
# [748]	valid_0's binary_logloss: 0.208775
# [749]	valid_0's binary_logloss: 0.208768
# [750]	valid_0's binary_logloss: 0.208762
# [751]	valid_0's binary_logloss: 0.208738
# [752]	valid_0's binary_logloss: 0.208775
# [753]	valid_0's binary_logloss: 0.208772
# [754]	valid_0's binary_logloss: 0.208759
# [755]	valid_0's binary_logloss: 0.208767
# [756]	valid_0's binary_logloss: 0.208765
# [757]	valid_0's binary_logloss: 0.208745
# [758]	valid_0's binary_logloss: 0.208742
# [759]	valid_0's binary_logloss: 0.208748
# [760]	valid_0's binary_logloss: 0.208724
# [761]	valid_0's binary_logloss: 0.208724
# [762]	valid_0's binary_logloss: 0.208729
# [763]	valid_0's binary_logloss: 0.20872
# [764]	valid_0's binary_logloss: 0.208705
# [765]	valid_0's binary_logloss: 0.2087
# [766]	valid_0's binary_logloss: 0.208688
# [767]	valid_0's binary_logloss: 0.208698
# [768]	valid_0's binary_logloss: 0.208703
# [769]	valid_0's binary_logloss: 0.208679
# [770]	valid_0's binary_logloss: 0.208677
# [771]	valid_0's binary_logloss: 0.208632
# [772]	valid_0's binary_logloss: 0.208618
# [773]	valid_0's binary_logloss: 0.208624
# [774]	valid_0's binary_logloss: 0.208659
# [775]	valid_0's binary_logloss: 0.208652
# [776]	valid_0's binary_logloss: 0.208657
# [777]	valid_0's binary_logloss: 0.208667
# [778]	valid_0's binary_logloss: 0.208707
# [779]	valid_0's binary_logloss: 0.208718
# [780]	valid_0's binary_logloss: 0.208704
# [781]	valid_0's binary_logloss: 0.20873
# [782]	valid_0's binary_logloss: 0.208733
# [783]	valid_0's binary_logloss: 0.208719
# [784]	valid_0's binary_logloss: 0.208723
# [785]	valid_0's binary_logloss: 0.208716
# [786]	valid_0's binary_logloss: 0.208735
# [787]	valid_0's binary_logloss: 0.208739
# [788]	valid_0's binary_logloss: 0.208748
# [789]	valid_0's binary_logloss: 0.208744
# [790]	valid_0's binary_logloss: 0.208753
# [791]	valid_0's binary_logloss: 0.208751
# [792]	valid_0's binary_logloss: 0.208763
# [793]	valid_0's binary_logloss: 0.208764
# [794]	valid_0's binary_logloss: 0.208752
# [795]	valid_0's binary_logloss: 0.208757
# [796]	valid_0's binary_logloss: 0.208767
# [797]	valid_0's binary_logloss: 0.208759
# [798]	valid_0's binary_logloss: 0.208777
# [799]	valid_0's binary_logloss: 0.20881
# [800]	valid_0's binary_logloss: 0.208807
# [801]	valid_0's binary_logloss: 0.208823
# [802]	valid_0's binary_logloss: 0.208838
# [803]	valid_0's binary_logloss: 0.208854
# [804]	valid_0's binary_logloss: 0.208853
# [805]	valid_0's binary_logloss: 0.208826
# [806]	valid_0's binary_logloss: 0.208847
# [807]	valid_0's binary_logloss: 0.208863
# [808]	valid_0's binary_logloss: 0.208868
# [809]	valid_0's binary_logloss: 0.208831
# [810]	valid_0's binary_logloss: 0.208811
# [811]	valid_0's binary_logloss: 0.208814
# [812]	valid_0's binary_logloss: 0.20883
# [813]	valid_0's binary_logloss: 0.208863
# [814]	valid_0's binary_logloss: 0.208845
# [815]	valid_0's binary_logloss: 0.208861
# [816]	valid_0's binary_logloss: 0.208852
# [817]	valid_0's binary_logloss: 0.208858
# [818]	valid_0's binary_logloss: 0.208858
# [819]	valid_0's binary_logloss: 0.208877
# [820]	valid_0's binary_logloss: 0.208868
# [821]	valid_0's binary_logloss: 0.20887
# [822]	valid_0's binary_logloss: 0.208891
# [823]	valid_0's binary_logloss: 0.208883
# [824]	valid_0's binary_logloss: 0.208885
# [825]	valid_0's binary_logloss: 0.208896
# [826]	valid_0's binary_logloss: 0.208904
# [827]	valid_0's binary_logloss: 0.208894
# [828]	valid_0's binary_logloss: 0.208885
# [829]	valid_0's binary_logloss: 0.208875
# [830]	valid_0's binary_logloss: 0.208876
# [831]	valid_0's binary_logloss: 0.208877
# [832]	valid_0's binary_logloss: 0.208881
# [833]	valid_0's binary_logloss: 0.208898
# [834]	valid_0's binary_logloss: 0.208898
# [835]	valid_0's binary_logloss: 0.208922
# [836]	valid_0's binary_logloss: 0.208924
# [837]	valid_0's binary_logloss: 0.208944
# [838]	valid_0's binary_logloss: 0.208963
# [839]	valid_0's binary_logloss: 0.208982
# [840]	valid_0's binary_logloss: 0.208981
# [841]	valid_0's binary_logloss: 0.208973
# [842]	valid_0's binary_logloss: 0.208984
# [843]	valid_0's binary_logloss: 0.208982
# [844]	valid_0's binary_logloss: 0.208979
# [845]	valid_0's binary_logloss: 0.208967
# [846]	valid_0's binary_logloss: 0.208962
# [847]	valid_0's binary_logloss: 0.20898
# [848]	valid_0's binary_logloss: 0.209014
# [849]	valid_0's binary_logloss: 0.209026
# [850]	valid_0's binary_logloss: 0.209031
# [851]	valid_0's binary_logloss: 0.209058
# [852]	valid_0's binary_logloss: 0.209059
# [853]	valid_0's binary_logloss: 0.209062
# [854]	valid_0's binary_logloss: 0.209076
# [855]	valid_0's binary_logloss: 0.209051
# [856]	valid_0's binary_logloss: 0.209048
# [857]	valid_0's binary_logloss: 0.209063
# [858]	valid_0's binary_logloss: 0.20905
# [859]	valid_0's binary_logloss: 0.209044
# [860]	valid_0's binary_logloss: 0.209036
# [861]	valid_0's binary_logloss: 0.20902
# [862]	valid_0's binary_logloss: 0.209035
# [863]	valid_0's binary_logloss: 0.209028
# [864]	valid_0's binary_logloss: 0.209015
# [865]	valid_0's binary_logloss: 0.209032
# [866]	valid_0's binary_logloss: 0.209047
# [867]	valid_0's binary_logloss: 0.209044
# [868]	valid_0's binary_logloss: 0.209037
# [869]	valid_0's binary_logloss: 0.209031
# [870]	valid_0's binary_logloss: 0.209047
# [871]	valid_0's binary_logloss: 0.209054
# [872]	valid_0's binary_logloss: 0.209087
# [873]	valid_0's binary_logloss: 0.209112
# [874]	valid_0's binary_logloss: 0.209105
# [875]	valid_0's binary_logloss: 0.209115
# [876]	valid_0's binary_logloss: 0.209142
# [877]	valid_0's binary_logloss: 0.209158
# [878]	valid_0's binary_logloss: 0.209141
# [879]	valid_0's binary_logloss: 0.209149
# [880]	valid_0's binary_logloss: 0.209125
# [881]	valid_0's binary_logloss: 0.209115
# [882]	valid_0's binary_logloss: 0.209099
# [883]	valid_0's binary_logloss: 0.209098
# [884]	valid_0's binary_logloss: 0.209119
# [885]	valid_0's binary_logloss: 0.209108
# [886]	valid_0's binary_logloss: 0.209128
# [887]	valid_0's binary_logloss: 0.209146
# [888]	valid_0's binary_logloss: 0.209156
# [889]	valid_0's binary_logloss: 0.209136
# [890]	valid_0's binary_logloss: 0.209135
# [891]	valid_0's binary_logloss: 0.209167
# [892]	valid_0's binary_logloss: 0.209171
# [893]	valid_0's binary_logloss: 0.209164
# [894]	valid_0's binary_logloss: 0.209168
# [895]	valid_0's binary_logloss: 0.209161
# [896]	valid_0's binary_logloss: 0.209164
# [897]	valid_0's binary_logloss: 0.209151
# [898]	valid_0's binary_logloss: 0.209146
# [899]	valid_0's binary_logloss: 0.209146
# [900]	valid_0's binary_logloss: 0.209148
# [901]	valid_0's binary_logloss: 0.209133
# [902]	valid_0's binary_logloss: 0.209147
# [903]	valid_0's binary_logloss: 0.209182
# [904]	valid_0's binary_logloss: 0.209185
# [905]	valid_0's binary_logloss: 0.209181
# [906]	valid_0's binary_logloss: 0.209203
# [907]	valid_0's binary_logloss: 0.209219
# [908]	valid_0's binary_logloss: 0.20923
# [909]	valid_0's binary_logloss: 0.209233
# [910]	valid_0's binary_logloss: 0.209251
# [911]	valid_0's binary_logloss: 0.209262
# [912]	valid_0's binary_logloss: 0.209274
# [913]	valid_0's binary_logloss: 0.209286
# [914]	valid_0's binary_logloss: 0.209303
# [915]	valid_0's binary_logloss: 0.209306
# [916]	valid_0's binary_logloss: 0.209334
# [917]	valid_0's binary_logloss: 0.20932
# [918]	valid_0's binary_logloss: 0.209343
# [919]	valid_0's binary_logloss: 0.209317
# [920]	valid_0's binary_logloss: 0.209316
# [921]	valid_0's binary_logloss: 0.209296
# [922]	valid_0's binary_logloss: 0.20931
# [923]	valid_0's binary_logloss: 0.209303
# [924]	valid_0's binary_logloss: 0.209323
# [925]	valid_0's binary_logloss: 0.209341
# [926]	valid_0's binary_logloss: 0.209354
# [927]	valid_0's binary_logloss: 0.209365
# [928]	valid_0's binary_logloss: 0.209385
# [929]	valid_0's binary_logloss: 0.209388
# [930]	valid_0's binary_logloss: 0.209379
# [931]	valid_0's binary_logloss: 0.209378
# [932]	valid_0's binary_logloss: 0.209398
# [933]	valid_0's binary_logloss: 0.209391
# [934]	valid_0's binary_logloss: 0.209413
# [935]	valid_0's binary_logloss: 0.209427
# [936]	valid_0's binary_logloss: 0.209463
# [937]	valid_0's binary_logloss: 0.209459
# [938]	valid_0's binary_logloss: 0.209444
# [939]	valid_0's binary_logloss: 0.209453
# [940]	valid_0's binary_logloss: 0.209448
# [941]	valid_0's binary_logloss: 0.209477
# [942]	valid_0's binary_logloss: 0.209493
# [943]	valid_0's binary_logloss: 0.209507
# [944]	valid_0's binary_logloss: 0.209539
# [945]	valid_0's binary_logloss: 0.209546
# [946]	valid_0's binary_logloss: 0.209559
# [947]	valid_0's binary_logloss: 0.209573
# [948]	valid_0's binary_logloss: 0.209614
# [949]	valid_0's binary_logloss: 0.209627
# [950]	valid_0's binary_logloss: 0.20963
# [951]	valid_0's binary_logloss: 0.209649
# [952]	valid_0's binary_logloss: 0.209652
# [953]	valid_0's binary_logloss: 0.209655
# [954]	valid_0's binary_logloss: 0.209693
# [955]	valid_0's binary_logloss: 0.209681
# [956]	valid_0's binary_logloss: 0.20969
# [957]	valid_0's binary_logloss: 0.209675
# [958]	valid_0's binary_logloss: 0.209674
# [959]	valid_0's binary_logloss: 0.209706
# [960]	valid_0's binary_logloss: 0.209705
# [961]	valid_0's binary_logloss: 0.209713
# [1265]	valid_0's binary_logloss: 0.207497
# [1266]	valid_0's binary_logloss: 0.207504
# [1267]	valid_0's binary_logloss: 0.207548
# [1268]	valid_0's binary_logloss: 0.207572
# [1269]	valid_0's binary_logloss: 0.207586
# [1270]	valid_0's binary_logloss: 0.207612
# [1271]	valid_0's binary_logloss: 0.207631
# [1272]	valid_0's binary_logloss: 0.207663
# [1273]	valid_0's binary_logloss: 0.207661
# [1274]	valid_0's binary_logloss: 0.207678
# [1275]	valid_0's binary_logloss: 0.207695
# [1276]	valid_0's binary_logloss: 0.207703
# [1277]	valid_0's binary_logloss: 0.207714
# [1278]	valid_0's binary_logloss: 0.20772
# [1279]	valid_0's binary_logloss: 0.207737
# [1280]	valid_0's binary_logloss: 0.207761
# [1281]	valid_0's binary_logloss: 0.207783
# [1282]	valid_0's binary_logloss: 0.207827
# [1283]	valid_0's binary_logloss: 0.20783
# [1284]	valid_0's binary_logloss: 0.20784
# [1285]	valid_0's binary_logloss: 0.20785
# [1286]	valid_0's binary_logloss: 0.207871
# [1287]	valid_0's binary_logloss: 0.207884
# [1288]	valid_0's binary_logloss: 0.207908
# [1289]	valid_0's binary_logloss: 0.207894
# [1290]	valid_0's binary_logloss: 0.207915
# [1291]	valid_0's binary_logloss: 0.207921
# [1292]	valid_0's binary_logloss: 0.207934
# [1293]	valid_0's binary_logloss: 0.207966
# [1294]	valid_0's binary_logloss: 0.207985
# [1295]	valid_0's binary_logloss: 0.208015
# [1296]	valid_0's binary_logloss: 0.208045
# [1297]	valid_0's binary_logloss: 0.208049
# [1298]	valid_0's binary_logloss: 0.208081
# [1299]	valid_0's binary_logloss: 0.208088
# [1300]	valid_0's binary_logloss: 0.208106
# [1301]	valid_0's binary_logloss: 0.208122
# [1302]	valid_0's binary_logloss: 0.208133
# [1303]	valid_0's binary_logloss: 0.208168
# [1304]	valid_0's binary_logloss: 0.208192
# [1305]	valid_0's binary_logloss: 0.208212
# [1306]	valid_0's binary_logloss: 0.208226
# [1307]	valid_0's binary_logloss: 0.20823
# [1308]	valid_0's binary_logloss: 0.208251
# [1309]	valid_0's binary_logloss: 0.208272
# [1310]	valid_0's binary_logloss: 0.208284
# [1311]	valid_0's binary_logloss: 0.208285
# [1312]	valid_0's binary_logloss: 0.20829
# [1313]	valid_0's binary_logloss: 0.208301
# [1314]	valid_0's binary_logloss: 0.208324
# [1315]	valid_0's binary_logloss: 0.208333
# [1316]	valid_0's binary_logloss: 0.208343
# [1317]	valid_0's binary_logloss: 0.208356
# [1318]	valid_0's binary_logloss: 0.208374
# [1319]	valid_0's binary_logloss: 0.208387
# [1320]	valid_0's binary_logloss: 0.20838
# [1321]	valid_0's binary_logloss: 0.208386
# [1322]	valid_0's binary_logloss: 0.208402
# [1323]	valid_0's binary_logloss: 0.208407
# [1324]	valid_0's binary_logloss: 0.20842
# [1325]	valid_0's binary_logloss: 0.208442
# [1326]	valid_0's binary_logloss: 0.208463
# [1327]	valid_0's binary_logloss: 0.208473
# [1392]	valid_0's binary_logloss: 0.209429
# [1393]	valid_0's binary_logloss: 0.209445
# [1394]	valid_0's binary_logloss: 0.20947
# [1395]	valid_0's binary_logloss: 0.209486
# [1396]	valid_0's binary_logloss: 0.209503
# [1397]	valid_0's binary_logloss: 0.209524
# [1398]	valid_0's binary_logloss: 0.209544
# [1399]	valid_0's binary_logloss: 0.209567
# [1400]	valid_0's binary_logloss: 0.209571
# [1401]	valid_0's binary_logloss: 0.209605
# [1402]	valid_0's binary_logloss: 0.209622
# [1403]	valid_0's binary_logloss: 0.209639
# [1404]	valid_0's binary_logloss: 0.209661
# [1405]	valid_0's binary_logloss: 0.209677
# [1406]	valid_0's binary_logloss: 0.209696
# [1407]	valid_0's binary_logloss: 0.209709
# [1408]	valid_0's binary_logloss: 0.209721
# [1409]	valid_0's binary_logloss: 0.209743
# [1410]	valid_0's binary_logloss: 0.209772
# [1411]	valid_0's binary_logloss: 0.209795
# [1412]	valid_0's binary_logloss: 0.209804
# [1413]	valid_0's binary_logloss: 0.209827
# [1414]	valid_0's binary_logloss: 0.209827
# [1415]	valid_0's binary_logloss: 0.209848
# [1416]	valid_0's binary_logloss: 0.209877
# [1417]	valid_0's binary_logloss: 0.209867
# [1418]	valid_0's binary_logloss: 0.209897
# [1419]	valid_0's binary_logloss: 0.209924
# [1420]	valid_0's binary_logloss: 0.209939
# [1421]	valid_0's binary_logloss: 0.209958
# [1422]	valid_0's binary_logloss: 0.210003
# [1423]	valid_0's binary_logloss: 0.210018
# [1424]	valid_0's binary_logloss: 0.210016
# [1425]	valid_0's binary_logloss: 0.210009
# [1426]	valid_0's binary_logloss: 0.210024
# [1427]	valid_0's binary_logloss: 0.210026
# [1428]	valid_0's binary_logloss: 0.210052
# [1429]	valid_0's binary_logloss: 0.210079
# [1430]	valid_0's binary_logloss: 0.210105
# [1431]	valid_0's binary_logloss: 0.210132
# [1432]	valid_0's binary_logloss: 0.21014
# [1433]	valid_0's binary_logloss: 0.21016
# [1434]	valid_0's binary_logloss: 0.210174
# [1435]	valid_0's binary_logloss: 0.210199
# [1436]	valid_0's binary_logloss: 0.210204
# [1437]	valid_0's binary_logloss: 0.210223
# [1438]	valid_0's binary_logloss: 0.210222
# [1439]	valid_0's binary_logloss: 0.210244
# [1440]	valid_0's binary_logloss: 0.21026
# [1441]	valid_0's binary_logloss: 0.210276
# [1442]	valid_0's binary_logloss: 0.210272
# [1443]	valid_0's binary_logloss: 0.21031
# [1444]	valid_0's binary_logloss: 0.210321
# [1445]	valid_0's binary_logloss: 0.210333
# [1446]	valid_0's binary_logloss: 0.210335
# [1447]	valid_0's binary_logloss: 0.210352
# [1448]	valid_0's binary_logloss: 0.210369
# [1449]	valid_0's binary_logloss: 0.210386
# [1450]	valid_0's binary_logloss: 0.210402
# [1451]	valid_0's binary_logloss: 0.210403
# [1452]	valid_0's binary_logloss: 0.21043
# [1453]	valid_0's binary_logloss: 0.210452
# [1454]	valid_0's binary_logloss: 0.210466
# [1518]	valid_0's binary_logloss: 0.211666
# [1519]	valid_0's binary_logloss: 0.211669
# [1520]	valid_0's binary_logloss: 0.211666
# [1521]	valid_0's binary_logloss: 0.211685
# [1522]	valid_0's binary_logloss: 0.211718
# [1523]	valid_0's binary_logloss: 0.21172
# [1524]	valid_0's binary_logloss: 0.211734
# [1525]	valid_0's binary_logloss: 0.211771
# [1526]	valid_0's binary_logloss: 0.211785
# [1527]	valid_0's binary_logloss: 0.211791
# [1528]	valid_0's binary_logloss: 0.211788
# [1529]	valid_0's binary_logloss: 0.211796
# [1530]	valid_0's binary_logloss: 0.211816
# [1531]	valid_0's binary_logloss: 0.211842
# [1532]	valid_0's binary_logloss: 0.211863
# [1533]	valid_0's binary_logloss: 0.211874
# [1534]	valid_0's binary_logloss: 0.211897
# [1535]	valid_0's binary_logloss: 0.211937
# [1536]	valid_0's binary_logloss: 0.21194
# [1537]	valid_0's binary_logloss: 0.211962
# [1538]	valid_0's binary_logloss: 0.211989
# [1539]	valid_0's binary_logloss: 0.211992
# [1540]	valid_0's binary_logloss: 0.212018
# [1541]	valid_0's binary_logloss: 0.212043
# [1542]	valid_0's binary_logloss: 0.212047
# [1543]	valid_0's binary_logloss: 0.212091
# [1544]	valid_0's binary_logloss: 0.212127
# [1545]	valid_0's binary_logloss: 0.212154
# [1546]	valid_0's binary_logloss: 0.212167
# [1547]	valid_0's binary_logloss: 0.212187
# [1548]	valid_0's binary_logloss: 0.212218
# [1549]	valid_0's binary_logloss: 0.212237
# [1550]	valid_0's binary_logloss: 0.212252
# [1551]	valid_0's binary_logloss: 0.212269
# [1552]	valid_0's binary_logloss: 0.212297
# [1553]	valid_0's binary_logloss: 0.212314
# [1554]	valid_0's binary_logloss: 0.212353
# [1555]	valid_0's binary_logloss: 0.212375
# [1556]	valid_0's binary_logloss: 0.212393
# [1557]	valid_0's binary_logloss: 0.212424
# [1558]	valid_0's binary_logloss: 0.212442
# [1559]	valid_0's binary_logloss: 0.212465
# [1560]	valid_0's binary_logloss: 0.212494
# [1561]	valid_0's binary_logloss: 0.212523
# [1562]	valid_0's binary_logloss: 0.212539
# [1563]	valid_0's binary_logloss: 0.212591
# [1564]	valid_0's binary_logloss: 0.212611
# [1565]	valid_0's binary_logloss: 0.212645
# [1566]	valid_0's binary_logloss: 0.212655
# [1567]	valid_0's binary_logloss: 0.212668
# [1568]	valid_0's binary_logloss: 0.212679
# [1569]	valid_0's binary_logloss: 0.2127
# [1570]	valid_0's binary_logloss: 0.212727
# [1571]	valid_0's binary_logloss: 0.212761
# [1572]	valid_0's binary_logloss: 0.21278
# [1573]	valid_0's binary_logloss: 0.212816
# [1574]	valid_0's binary_logloss: 0.212856
# [1575]	valid_0's binary_logloss: 0.212861
# [1576]	valid_0's binary_logloss: 0.212872
# [1577]	valid_0's binary_logloss: 0.212897
# [1578]	valid_0's binary_logloss: 0.212919
# [1579]	valid_0's binary_logloss: 0.212927
# [1580]	valid_0's binary_logloss: 0.212959
# [1581]	valid_0's binary_logloss: 0.212996
# [1582]	valid_0's binary_logloss: 0.213032
# [1583]	valid_0's binary_logloss: 0.213064
# [1584]	valid_0's binary_logloss: 0.213077
# [1585]	valid_0's binary_logloss: 0.213081
# [1586]	valid_0's binary_logloss: 0.213088
# [1587]	valid_0's binary_logloss: 0.213116
# [1588]	valid_0's binary_logloss: 0.213131
# [1589]	valid_0's binary_logloss: 0.213156
# [1590]	valid_0's binary_logloss: 0.213166
# [1591]	valid_0's binary_logloss: 0.213185
# [1592]	valid_0's binary_logloss: 0.213205
# [1593]	valid_0's binary_logloss: 0.213238
# [1594]	valid_0's binary_logloss: 0.213247
# [1595]	valid_0's binary_logloss: 0.213253
# [1596]	valid_0's binary_logloss: 0.213291
# [1597]	valid_0's binary_logloss: 0.213315
# [1598]	valid_0's binary_logloss: 0.213354
# [1599]	valid_0's binary_logloss: 0.213378
# [1600]	valid_0's binary_logloss: 0.213389
# Accuracy on fold 5: 0.9247
# Mean accuracies: 0.923915
# List of accuracies: [0.9227, 0.92585, 0.92235, 0.923975, 0.9247]

# %%
# ============================================================================
# Final predictions on test set
# ============================================================================

# Get the original id codes
sub = pd.DataFrame({"ID_code": test_codes})
av_sub = pd.DataFrame({"ID_code": test_codes})

pred_real = model.predict(test)
pred_synth = model.predict(synth)

# Make predictions on the real and synthetic sets seperately then concatenate for final pred
preds_all = np.zeros(test_length)
preds_all[real_idx] = pred_real
preds_all[synth_idx] = pred_synth

# Prediction on best result from 5-fold cv
sub["target"] = preds_all
sub.to_csv("submission.csv", index=False)
print(f"Best result sub: {sub.head(20)}")

# Prediction on average result from 5-fold cv
av_sub["target"] = av_preds_all
av_sub.to_csv("av_submission0.csv", index=False)
print(f"Average result sub: {av_sub.head(20)}")

j = 0
for i in model:
  model.save_model('/content/drive/MyDrive/STAT4450_contest2_data/models/fivecv_lgbm' + str(j) + '.txt')
  j = j + 1
# Out:
# Best result sub:     ID_code    target
# 0    test_0  1.000000
# 1    test_1  1.000000
# 2    test_2  1.000000
# 3    test_3  0.213761
# 4    test_4  1.000000
# 5    test_5  1.000000
# 6    test_6  1.000000
# 7    test_7  0.027681
# 8    test_8  1.000000
# 9    test_9  1.000000
# 10  test_10  1.000000
# 11  test_11  0.006097
# 12  test_12  1.000000
# 13  test_13  1.000000
# 14  test_14  1.000000
# 15  test_15  0.017834
# 16  test_16  0.294565
# 17  test_17  0.011540
# 18  test_18  0.026875
# 19  test_19  1.000000
# Average result sub:     ID_code    target
# 0    test_0  1.000000
# 1    test_1  1.000000
# 2    test_2  1.000000
# 3    test_3  0.134592
# 4    test_4  1.000000
# 5    test_5  1.000000
# 6    test_6  1.000000
# 7    test_7  0.033468
# 8    test_8  1.000000
# 9    test_9  1.000000
# 10  test_10  1.000000
# 11  test_11  0.012267
# 12  test_12  1.000000
# 13  test_13  1.000000
# 14  test_14  1.000000
# 15  test_15  0.015017
# 16  test_16  0.322596
# 17  test_17  0.012207
# 18  test_18  0.059600
# 19  test_19  1.000000

# %% [markdown]
# Convolutional Neural Network, fastai

# %%
# note, lgbm model is called "model"
val_idx = x_val.index.tolist()
train_df = pd.concat([pd.DataFrame(train),pd.DataFrame(target)],axis=1)
train_df.rename(columns={0:'target'},inplace=True)
y_block = CategoryBlock()
dls = TabularDataLoaders.from_df(train_df, y_names='target',y_block=y_block,valid_idx=val_idx, bs=64)
learn = tabular_learner(dls,[200,100], metrics=[accuracy, RocAucBinary()])
learn.fit_one_cycle(3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.226951</td>
#       <td>0.229047</td>
#       <td>0.914467</td>
#       <td>0.868228</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.224810</td>
#       <td>0.221603</td>
#       <td>0.917317</td>
#       <td>0.877395</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.170307</td>
#       <td>0.233712</td>
#       <td>0.913167</td>
#       <td>0.872641</td>
#       <td>00:38</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_test = pd.DataFrame(test)
df_synth = pd.DataFrame(synth)
dl = learn.dls.test_dl(df_test)
dl2 = learn.dls.test_dl(df_synth)
preds1 = learn.get_preds(dl=dl)
preds2 = learn.get_preds(dl=dl2)

preds_all = np.zeros(test_length)
preds_all[real_idx] = preds1[0][:,1].tolist()
preds_all[synth_idx] = preds2[0][:,1].tolist()

# Prediction on best result from 5-fold cv
sub = pd.DataFrame({"ID_code": test_codes})
sub["target"] = preds_all
sub.to_csv("/content/drive/MyDrive/STAT4450_contest2_data/nnsubmission0.csv", index=False)
print(sub.head(20))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     ID_code    target
# 0    test_0  1.000000
# 1    test_1  1.000000
# 2    test_2  1.000000
# 3    test_3  0.110570
# 4    test_4  1.000000
# 5    test_5  1.000000
# 6    test_6  1.000000
# 7    test_7  0.111808
# 8    test_8  1.000000
# 9    test_9  1.000000
# 10  test_10  1.000000
# 11  test_11  0.009460
# 12  test_12  1.000000
# 13  test_13  1.000000
# 14  test_14  1.000000
# 15  test_15  0.000953
# 16  test_16  0.195976
# 17  test_17  0.008303
# 18  test_18  0.246055
# 19  test_19  1.000000

# %% [markdown]
# Combining LGBM and CNN

# %%
from sklearn.linear_model import LogisticRegression

# combining the predictions to make a new feature matrix
df_val = pd.DataFrame(x_val)
df_val.rename(columns={0:'target'},inplace=True)
dl = learn.dls.test_dl(df_val)
lgb_preds = model.predict(x_val)
cnn_preds = learn.get_preds(dl=dl)[0][:,0]
combined_preds = np.hstack((lgb_preds.reshape((-1, 1)), cnn_preds.reshape((-1, 1))))

# meta model training
# meta_model = LogisticRegression()
# meta_model.fit(combined_preds,y_val)
train_data = lgb.Dataset(combined_preds, label=y_val)
meta_model = lgb.train(params, train_data, num_rounds)

# preprocessing final test data
df_test = pd.concat([pd.DataFrame(test),pd.DataFrame(synth)],axis=0)
df_test.rename(columns={0:'target'},inplace=True)
dl = learn.dls.test_dl(df_test)

# Getting predictions to make final predictions
lgb_test_preds_real = model.predict(test)
lgb_test_preds_synth = model.predict(synth)
lgb_test_preds_both = np.concatenate([lgb_test_preds_real,lgb_test_preds_synth])
cnn_test_preds_both = learn.get_preds(dl=dl)[0][:,0]
test_combined_preds = np.hstack((lgb_test_preds_both.reshape(-1, 1), cnn_test_preds_both.reshape(-1, 1)))
final_preds = meta_model.predict(test_combined_preds)

# Make final prediction for test
sub = pd.DataFrame({"ID_code": test_codes})

preds_all = np.zeros(test_length)
preds_all[real_idx] = final_preds[real_idx]
preds_all[synth_idx] = final_preds[synth_idx]

sub["target"] = preds_all
sub.to_csv("/content/drive/MyDrive/STAT4450_contest2_data/stacksubmission1.csv", index=False)
print(sub.head(20))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-75cb8b2152bf> in <cell line: 15>()
#      13 # meta_model.fit(combined_preds,y_val)
#      14 train_data = lgb.Dataset(combined_preds, label=y_val)
# ---> 15 meta_model = lgb.train(params, train_data, num_rounds)
#      16
#      17 # preprocessing final test data
#
# /usr/local/lib/python3.9/dist-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     269     # construct booster
#     270     try:
# --> 271         booster = Booster(params=params, train_set=train_set)
#     272         if is_valid_contain_train:
#     273             booster.set_train_data_name(train_data_name)
#
# /usr/local/lib/python3.9/dist-packages/lightgbm/basic.py in __init__(self, params, train_set, model_file, model_str, silent)
#    2603                 )
#    2604             # construct booster object
# -> 2605             train_set.construct()
#    2606             # copy the parameters from train_set
#    2607             params.update(train_set.get_params())
#
# /usr/local/lib/python3.9/dist-packages/lightgbm/basic.py in construct(self)
#    1813             else:
#    1814                 # create train
# -> 1815                 self._lazy_init(self.data, label=self.label,
#    1816                                 weight=self.weight, group=self.group,
#    1817                                 init_score=self.init_score, predictor=self._predictor,
#
# /usr/local/lib/python3.9/dist-packages/lightgbm/basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#    1536             self.__init_from_csc(data, params_str, ref_dataset)
#    1537         elif isinstance(data, np.ndarray):
# -> 1538             self.__init_from_np2d(data, params_str, ref_dataset)
#    1539         elif isinstance(data, list) and len(data) > 0:
#    1540             if all(isinstance(x, np.ndarray) for x in data):
#
# /usr/local/lib/python3.9/dist-packages/lightgbm/basic.py in __init_from_np2d(self, mat, params_str, ref_dataset)
#    1648         """Initialize data from a 2-D numpy matrix."""
#    1649         if len(mat.shape) != 2:
# -> 1650             raise ValueError('Input numpy.ndarray must be 2 dimensional')
#    1651
#    1652         self.handle = ctypes.c_void_p()
#
# ValueError: Input numpy.ndarray must be 2 dimensional

# %% [markdown]
# Neural Network from Scratch

# %%
from re import X
# Predicting with a neural net
df_train = pd.concat([pd.DataFrame(train),pd.DataFrame(target)], axis=1)
df_train.rename(columns={0:'target'},inplace=True)
splits = RandomSplitter()(range_of(df_train))
y_names = 'target'
cont_names = df_train.columns.tolist()[-len(df_train.columns.tolist())]
procs = [FillMissing, Normalize]
y_block = CategoryBlock()

# Building TabularPandas
to = TabularPandas(df_train.reset_index(), procs=procs, cont_names=cont_names, y_names=y_names, y_block=y_block, splits=splits)

## creating a dataloader
dls = to.dataloaders()

learn = tabular_learner(dls,[200,100],metrics=accuracy)

# Training the NN
learn.fit_one_cycle(10)
learn.lr_find()
result = learn.validate()
print(result)

# %%
# TODO: Make predictions for submit to Kaggle
df_test = pd.concat([pd.DataFrame(test),pd.DataFrame(synth)],axis=0)
dl = learn.dls.test_dl(df_test)
preds = learn.get_preds(dl=dl)
result = learn.validate()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
target = pd.DataFrame(preds[0][:,0].tolist())
ID_codes = pd.DataFrame(pd.read_csv("/content/drive/MyDrive/STAT4450_contest2_data/test.csv")['ID_code'])
submission0 = pd.concat([ID_codes,target],axis=1)
submission0.columns = list(["ID_code","target"])
submission0.to_csv("/content/drive/MyDrive/STAT4450_contest2_data/submission0.csv", index=False)
